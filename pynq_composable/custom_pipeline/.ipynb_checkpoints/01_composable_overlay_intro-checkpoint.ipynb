# %% [markdown]
# # Composable Overlay Introduction
# ----
#
# <div class="alert alert-box alert-info">
# Please use Jupyter labs http://&lt;board_ip_address&gt;/lab for this notebook.
# </div>
#
# This notebook provides an introductory overview of the Composable Overlay and how to use it from a Jupyter Notebook
#
# ## Aims
# * Describe the Composable Pipeline architecture
# * Explore the `Composable` class
#
# ## Table of Contents
# * [Introduction](#intro)
# * [The Composable Class](#composable_class)
# * [Download the Composable Overlay](#download)
# * [Explore Composable Dictionary](#c_dict)
# * [Explore DFX Dictionary](#dfx_dict)
# * [Documentation](#docs)
# * [Conclusion](#conclusion)
#
# ## Revision History
#
# * v1.0 | 30 March 2021 | First notebook revision.
# * v1.1 | 11 August 2021 | Update notebook to composable overlay API 1.0.0
#
# ----

# %% [markdown]
# ## Introduction <a class="anchor" id="intro"></a>
#
# A Composable Overlay is an overlay with a novel and clever architecture that allow us to adapt how the data flows between the IP cores connected to the switch.
#
# The key characteristic of a composable overlay is an AXI4-Stream Switch at its core, which plays the same role as an old [telephone switchboard](https://en.wikipedia.org/wiki/Telephone_switchboard). The AXI4-Stream Switch provides the runtime routing of the data flow from one IP to another in a one to one manner.
#
# On top of that, the composable overlay includes DFX (partial reconfigurable) regions that can bring new functionality to the design.
#
# The composable overlay architecture of a composable video overlay for the PYNQ-Z2 is shown in the image below
#
# ![](../img/cv-4pr.png)

# %% [markdown]
# ## The Composable Class <a class="anchor" id="composable_class"></a>
#
# The `Composable` class inherits from the pynq [`DefaultHierarchy` class](https://pynq.readthedocs.io/en/latest/pynq_package/pynq.overlay.html?#pynq.overlay.DefaultHierarchy) and enhances it by adding new methods and attributes to compose pipelines at run time.
# The `Composable` class abstracts the Composable Overlay logic in a pythonic way, pynq assigns this class (driver) to any hierarchy that contains and [AXI4-Stream Switch](https://www.xilinx.com/products/intellectual-property/axi4-stream_interconnect.html#documentation) (`axis_switch`) and [AXI GPIO](https://www.xilinx.com/products/intellectual-property/axi_gpio.html#documentation) for soft reset (`pipeline_control`).

# %% [markdown]
# ## Download the Composable Overlay <a class="anchor" id="download"></a>
#
# It is time to download the composable overlay using the `pynq.Overlay` class and grab a handler to the `.composable` hierarchy.
#
# pynq will automatically assign the `Composable` class to the `.composable` hierarchy given that its meets requirements.
#
# The `Overlay` class will:
#
# 1. Download the bitstream onto the FPGA

# %%
from pynq import Overlay
import pynq_composable

ol = Overlay("cv_dfx_3_pr.bit")

# %%
ol.hierarchy_dict
# Out:
# {'composable': {'ip': {'axis_switch': {'type': 'xilinx.com:ip:axis_switch:1.1',
#     'mem_id': 'S_AXI_CTRL',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_FAMILY': 'zynquplus',
#      'C_NUM_SI_SLOTS': '16',
#      'C_LOG_SI_SLOTS': '4',
#      'C_NUM_MI_SLOTS': '15',
#      'C_AXIS_TDATA_WIDTH': '24',
#      'C_AXIS_TID_WIDTH': '1',
#      'C_AXIS_TDEST_WIDTH': '1',
#      'C_AXIS_TUSER_WIDTH': '1',
#      'C_AXIS_SIGNAL_SET': '0b00000000000000000000000010010011',
#      'C_ARB_ON_MAX_XFERS': '1',
#      'C_ARB_ON_NUM_CYCLES': '0',
#      'C_ARB_ON_TLAST': '0',
#      'C_INCLUDE_ARBITER': '1',
#      'C_ARB_ALGORITHM': '0',
#      'C_OUTPUT_REG': '0',
#      'C_DECODER_REG': '1',
#      'C_M_AXIS_CONNECTIVITY_ARRAY': '0b111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111',
#      'C_M_AXIS_BASETDEST_ARRAY': '0b010101010101010',
#      'C_M_AXIS_HIGHTDEST_ARRAY': '0b010101010101010',
#      'C_ROUTING_MODE': '1',
#      'C_S_AXI_CTRL_ADDR_WIDTH': '7',
#      'C_S_AXI_CTRL_DATA_WIDTH': '32',
#      'C_COMMON_CLOCK': '0',
#      'NUM_SI': '16',
#      'NUM_MI': '15',
#      'ROUTING_MODE': '1',
#      'HAS_TREADY': '1',
#      'TDATA_NUM_BYTES': '3',
#      'HAS_TSTRB': '0',
#      'HAS_TKEEP': '0',
#      'HAS_TLAST': '1',
#      'TID_WIDTH': '0',
#      'TDEST_WIDTH': '0',
#      'TUSER_WIDTH': '1',
#      'HAS_ACLKEN': '0',
#      'ARB_ON_MAX_XFERS': '1',
#      'ARB_ON_NUM_CYCLES': '0',
#      'ARB_ON_TLAST': '0',
#      'ARB_ALGORITHM': '0',
#      'DECODER_REG': '1',
#      'OUTPUT_REG': '0',
#      'COMMON_CLOCK': '0',
#      'M00_AXIS_BASETDEST': '0x00000000',
#      'M01_AXIS_BASETDEST': '0x00000001',
#      'M02_AXIS_BASETDEST': '0x00000002',
#      'M03_AXIS_BASETDEST': '0x00000003',
#      'M04_AXIS_BASETDEST': '0x00000004',
#      'M05_AXIS_BASETDEST': '0x00000005',
#      'M06_AXIS_BASETDEST': '0x00000006',
#      'M07_AXIS_BASETDEST': '0x00000007',
#      'M08_AXIS_BASETDEST': '0x00000008',
#      'M09_AXIS_BASETDEST': '0x00000009',
#      'M10_AXIS_BASETDEST': '0x0000000a',
#      'M11_AXIS_BASETDEST': '0x0000000b',
#      'M12_AXIS_BASETDEST': '0x0000000c',
#      'M13_AXIS_BASETDEST': '0x0000000d',
#      'M14_AXIS_BASETDEST': '0x0000000e',
#      'M15_AXIS_BASETDEST': '0x0000000f',
#      'M00_AXIS_HIGHTDEST': '0x00000000',
#      'M01_AXIS_HIGHTDEST': '0x00000001',
#      'M02_AXIS_HIGHTDEST': '0x00000002',
#      'M03_AXIS_HIGHTDEST': '0x00000003',
#      'M04_AXIS_HIGHTDEST': '0x00000004',
#      'M05_AXIS_HIGHTDEST': '0x00000005',
#      'M06_AXIS_HIGHTDEST': '0x00000006',
#      'M07_AXIS_HIGHTDEST': '0x00000007',
#      'M08_AXIS_HIGHTDEST': '0x00000008',
#      'M09_AXIS_HIGHTDEST': '0x00000009',
#      'M10_AXIS_HIGHTDEST': '0x0000000a',
#      'M11_AXIS_HIGHTDEST': '0x0000000b',
#      'M12_AXIS_HIGHTDEST': '0x0000000c',
#      'M13_AXIS_HIGHTDEST': '0x0000000d',
#      'M14_AXIS_HIGHTDEST': '0x0000000e',
#      'M15_AXIS_HIGHTDEST': '0x0000000f',
#      'M00_S00_CONNECTIVITY': '1',
#      'M00_S01_CONNECTIVITY': '1',
#      'M00_S02_CONNECTIVITY': '1',
#      'M00_S03_CONNECTIVITY': '1',
#      'M00_S04_CONNECTIVITY': '1',
#      'M00_S05_CONNECTIVITY': '1',
#      'M00_S06_CONNECTIVITY': '1',
#      'M00_S07_CONNECTIVITY': '1',
#      'M00_S08_CONNECTIVITY': '1',
#      'M00_S09_CONNECTIVITY': '1',
#      'M00_S10_CONNECTIVITY': '1',
#      'M00_S11_CONNECTIVITY': '1',
#      'M00_S12_CONNECTIVITY': '1',
#      'M00_S13_CONNECTIVITY': '1',
#      'M00_S14_CONNECTIVITY': '1',
#      'M00_S15_CONNECTIVITY': '1',
#      'M01_S00_CONNECTIVITY': '1',
#      'M01_S01_CONNECTIVITY': '1',
#      'M01_S02_CONNECTIVITY': '1',
#      'M01_S03_CONNECTIVITY': '1',
#      'M01_S04_CONNECTIVITY': '1',
#      'M01_S05_CONNECTIVITY': '1',
#      'M01_S06_CONNECTIVITY': '1',
#      'M01_S07_CONNECTIVITY': '1',
#      'M01_S08_CONNECTIVITY': '1',
#      'M01_S09_CONNECTIVITY': '1',
#      'M01_S10_CONNECTIVITY': '1',
#      'M01_S11_CONNECTIVITY': '1',
#      'M01_S12_CONNECTIVITY': '1',
#      'M01_S13_CONNECTIVITY': '1',
#      'M01_S14_CONNECTIVITY': '1',
#      'M01_S15_CONNECTIVITY': '1',
#      'M02_S00_CONNECTIVITY': '1',
#      'M02_S01_CONNECTIVITY': '1',
#      'M02_S02_CONNECTIVITY': '1',
#      'M02_S03_CONNECTIVITY': '1',
#      'M02_S04_CONNECTIVITY': '1',
#      'M02_S05_CONNECTIVITY': '1',
#      'M02_S06_CONNECTIVITY': '1',
#      'M02_S07_CONNECTIVITY': '1',
#      'M02_S08_CONNECTIVITY': '1',
#      'M02_S09_CONNECTIVITY': '1',
#      'M02_S10_CONNECTIVITY': '1',
#      'M02_S11_CONNECTIVITY': '1',
#      'M02_S12_CONNECTIVITY': '1',
#      'M02_S13_CONNECTIVITY': '1',
#      'M02_S14_CONNECTIVITY': '1',
#      'M02_S15_CONNECTIVITY': '1',
#      'M03_S00_CONNECTIVITY': '1',
#      'M03_S01_CONNECTIVITY': '1',
#      'M03_S02_CONNECTIVITY': '1',
#      'M03_S03_CONNECTIVITY': '1',
#      'M03_S04_CONNECTIVITY': '1',
#      'M03_S05_CONNECTIVITY': '1',
#      'M03_S06_CONNECTIVITY': '1',
#      'M03_S07_CONNECTIVITY': '1',
#      'M03_S08_CONNECTIVITY': '1',
#      'M03_S09_CONNECTIVITY': '1',
#      'M03_S10_CONNECTIVITY': '1',
#      'M03_S11_CONNECTIVITY': '1',
#      'M03_S12_CONNECTIVITY': '1',
#      'M03_S13_CONNECTIVITY': '1',
#      'M03_S14_CONNECTIVITY': '1',
#      'M03_S15_CONNECTIVITY': '1',
#      'M04_S00_CONNECTIVITY': '1',
#      'M04_S01_CONNECTIVITY': '1',
#      'M04_S02_CONNECTIVITY': '1',
#      'M04_S03_CONNECTIVITY': '1',
#      'M04_S04_CONNECTIVITY': '1',
#      'M04_S05_CONNECTIVITY': '1',
#      'M04_S06_CONNECTIVITY': '1',
#      'M04_S07_CONNECTIVITY': '1',
#      'M04_S08_CONNECTIVITY': '1',
#      'M04_S09_CONNECTIVITY': '1',
#      'M04_S10_CONNECTIVITY': '1',
#      'M04_S11_CONNECTIVITY': '1',
#      'M04_S12_CONNECTIVITY': '1',
#      'M04_S13_CONNECTIVITY': '1',
#      'M04_S14_CONNECTIVITY': '1',
#      'M04_S15_CONNECTIVITY': '1',
#      'M05_S00_CONNECTIVITY': '1',
#      'M05_S01_CONNECTIVITY': '1',
#      'M05_S02_CONNECTIVITY': '1',
#      'M05_S03_CONNECTIVITY': '1',
#      'M05_S04_CONNECTIVITY': '1',
#      'M05_S05_CONNECTIVITY': '1',
#      'M05_S06_CONNECTIVITY': '1',
#      'M05_S07_CONNECTIVITY': '1',
#      'M05_S08_CONNECTIVITY': '1',
#      'M05_S09_CONNECTIVITY': '1',
#      'M05_S10_CONNECTIVITY': '1',
#      'M05_S11_CONNECTIVITY': '1',
#      'M05_S12_CONNECTIVITY': '1',
#      'M05_S13_CONNECTIVITY': '1',
#      'M05_S14_CONNECTIVITY': '1',
#      'M05_S15_CONNECTIVITY': '1',
#      'M06_S00_CONNECTIVITY': '1',
#      'M06_S01_CONNECTIVITY': '1',
#      'M06_S02_CONNECTIVITY': '1',
#      'M06_S03_CONNECTIVITY': '1',
#      'M06_S04_CONNECTIVITY': '1',
#      'M06_S05_CONNECTIVITY': '1',
#      'M06_S06_CONNECTIVITY': '1',
#      'M06_S07_CONNECTIVITY': '1',
#      'M06_S08_CONNECTIVITY': '1',
#      'M06_S09_CONNECTIVITY': '1',
#      'M06_S10_CONNECTIVITY': '1',
#      'M06_S11_CONNECTIVITY': '1',
#      'M06_S12_CONNECTIVITY': '1',
#      'M06_S13_CONNECTIVITY': '1',
#      'M06_S14_CONNECTIVITY': '1',
#      'M06_S15_CONNECTIVITY': '1',
#      'M07_S00_CONNECTIVITY': '1',
#      'M07_S01_CONNECTIVITY': '1',
#      'M07_S02_CONNECTIVITY': '1',
#      'M07_S03_CONNECTIVITY': '1',
#      'M07_S04_CONNECTIVITY': '1',
#      'M07_S05_CONNECTIVITY': '1',
#      'M07_S06_CONNECTIVITY': '1',
#      'M07_S07_CONNECTIVITY': '1',
#      'M07_S08_CONNECTIVITY': '1',
#      'M07_S09_CONNECTIVITY': '1',
#      'M07_S10_CONNECTIVITY': '1',
#      'M07_S11_CONNECTIVITY': '1',
#      'M07_S12_CONNECTIVITY': '1',
#      'M07_S13_CONNECTIVITY': '1',
#      'M07_S14_CONNECTIVITY': '1',
#      'M07_S15_CONNECTIVITY': '1',
#      'M08_S00_CONNECTIVITY': '1',
#      'M08_S01_CONNECTIVITY': '1',
#      'M08_S02_CONNECTIVITY': '1',
#      'M08_S03_CONNECTIVITY': '1',
#      'M08_S04_CONNECTIVITY': '1',
#      'M08_S05_CONNECTIVITY': '1',
#      'M08_S06_CONNECTIVITY': '1',
#      'M08_S07_CONNECTIVITY': '1',
#      'M08_S08_CONNECTIVITY': '1',
#      'M08_S09_CONNECTIVITY': '1',
#      'M08_S10_CONNECTIVITY': '1',
#      'M08_S11_CONNECTIVITY': '1',
#      'M08_S12_CONNECTIVITY': '1',
#      'M08_S13_CONNECTIVITY': '1',
#      'M08_S14_CONNECTIVITY': '1',
#      'M08_S15_CONNECTIVITY': '1',
#      'M09_S00_CONNECTIVITY': '1',
#      'M09_S01_CONNECTIVITY': '1',
#      'M09_S02_CONNECTIVITY': '1',
#      'M09_S03_CONNECTIVITY': '1',
#      'M09_S04_CONNECTIVITY': '1',
#      'M09_S05_CONNECTIVITY': '1',
#      'M09_S06_CONNECTIVITY': '1',
#      'M09_S07_CONNECTIVITY': '1',
#      'M09_S08_CONNECTIVITY': '1',
#      'M09_S09_CONNECTIVITY': '1',
#      'M09_S10_CONNECTIVITY': '1',
#      'M09_S11_CONNECTIVITY': '1',
#      'M09_S12_CONNECTIVITY': '1',
#      'M09_S13_CONNECTIVITY': '1',
#      'M09_S14_CONNECTIVITY': '1',
#      'M09_S15_CONNECTIVITY': '1',
#      'M10_S00_CONNECTIVITY': '1',
#      'M10_S01_CONNECTIVITY': '1',
#      'M10_S02_CONNECTIVITY': '1',
#      'M10_S03_CONNECTIVITY': '1',
#      'M10_S04_CONNECTIVITY': '1',
#      'M10_S05_CONNECTIVITY': '1',
#      'M10_S06_CONNECTIVITY': '1',
#      'M10_S07_CONNECTIVITY': '1',
#      'M10_S08_CONNECTIVITY': '1',
#      'M10_S09_CONNECTIVITY': '1',
#      'M10_S10_CONNECTIVITY': '1',
#      'M10_S11_CONNECTIVITY': '1',
#      'M10_S12_CONNECTIVITY': '1',
#      'M10_S13_CONNECTIVITY': '1',
#      'M10_S14_CONNECTIVITY': '1',
#      'M10_S15_CONNECTIVITY': '1',
#      'M11_S00_CONNECTIVITY': '1',
#      'M11_S01_CONNECTIVITY': '1',
#      'M11_S02_CONNECTIVITY': '1',
#      'M11_S03_CONNECTIVITY': '1',
#      'M11_S04_CONNECTIVITY': '1',
#      'M11_S05_CONNECTIVITY': '1',
#      'M11_S06_CONNECTIVITY': '1',
#      'M11_S07_CONNECTIVITY': '1',
#      'M11_S08_CONNECTIVITY': '1',
#      'M11_S09_CONNECTIVITY': '1',
#      'M11_S10_CONNECTIVITY': '1',
#      'M11_S11_CONNECTIVITY': '1',
#      'M11_S12_CONNECTIVITY': '1',
#      'M11_S13_CONNECTIVITY': '1',
#      'M11_S14_CONNECTIVITY': '1',
#      'M11_S15_CONNECTIVITY': '1',
#      'M12_S00_CONNECTIVITY': '1',
#      'M12_S01_CONNECTIVITY': '1',
#      'M12_S02_CONNECTIVITY': '1',
#      'M12_S03_CONNECTIVITY': '1',
#      'M12_S04_CONNECTIVITY': '1',
#      'M12_S05_CONNECTIVITY': '1',
#      'M12_S06_CONNECTIVITY': '1',
#      'M12_S07_CONNECTIVITY': '1',
#      'M12_S08_CONNECTIVITY': '1',
#      'M12_S09_CONNECTIVITY': '1',
#      'M12_S10_CONNECTIVITY': '1',
#      'M12_S11_CONNECTIVITY': '1',
#      'M12_S12_CONNECTIVITY': '1',
#      'M12_S13_CONNECTIVITY': '1',
#      'M12_S14_CONNECTIVITY': '1',
#      'M12_S15_CONNECTIVITY': '1',
#      'M13_S00_CONNECTIVITY': '1',
#      'M13_S01_CONNECTIVITY': '1',
#      'M13_S02_CONNECTIVITY': '1',
#      'M13_S03_CONNECTIVITY': '1',
#      'M13_S04_CONNECTIVITY': '1',
#      'M13_S05_CONNECTIVITY': '1',
#      'M13_S06_CONNECTIVITY': '1',
#      'M13_S07_CONNECTIVITY': '1',
#      'M13_S08_CONNECTIVITY': '1',
#      'M13_S09_CONNECTIVITY': '1',
#      'M13_S10_CONNECTIVITY': '1',
#      'M13_S11_CONNECTIVITY': '1',
#      'M13_S12_CONNECTIVITY': '1',
#      'M13_S13_CONNECTIVITY': '1',
#      'M13_S14_CONNECTIVITY': '1',
#      'M13_S15_CONNECTIVITY': '1',
#      'M14_S00_CONNECTIVITY': '1',
#      'M14_S01_CONNECTIVITY': '1',
#      'M14_S02_CONNECTIVITY': '1',
#      'M14_S03_CONNECTIVITY': '1',
#      'M14_S04_CONNECTIVITY': '1',
#      'M14_S05_CONNECTIVITY': '1',
#      'M14_S06_CONNECTIVITY': '1',
#      'M14_S07_CONNECTIVITY': '1',
#      'M14_S08_CONNECTIVITY': '1',
#      'M14_S09_CONNECTIVITY': '1',
#      'M14_S10_CONNECTIVITY': '1',
#      'M14_S11_CONNECTIVITY': '1',
#      'M14_S12_CONNECTIVITY': '1',
#      'M14_S13_CONNECTIVITY': '1',
#      'M14_S14_CONNECTIVITY': '1',
#      'M14_S15_CONNECTIVITY': '1',
#      'M15_S00_CONNECTIVITY': '1',
#      'M15_S01_CONNECTIVITY': '1',
#      'M15_S02_CONNECTIVITY': '1',
#      'M15_S03_CONNECTIVITY': '1',
#      'M15_S04_CONNECTIVITY': '1',
#      'M15_S05_CONNECTIVITY': '1',
#      'M15_S06_CONNECTIVITY': '1',
#      'M15_S07_CONNECTIVITY': '1',
#      'M15_S08_CONNECTIVITY': '1',
#      'M15_S09_CONNECTIVITY': '1',
#      'M15_S10_CONNECTIVITY': '1',
#      'M15_S11_CONNECTIVITY': '1',
#      'M15_S12_CONNECTIVITY': '1',
#      'M15_S13_CONNECTIVITY': '1',
#      'M15_S14_CONNECTIVITY': '1',
#      'M15_S15_CONNECTIVITY': '1',
#      'Component_Name': 'video_cp_axis_switch_0',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_BASEADDR': '0x800B0000',
#      'C_HIGHADDR': '0x800BFFFF',
#      'FREQ_HZ': '299997009',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'LAYERED_METADATA': 'undef',
#      'INSERT_VIP': '0',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'ID_WIDTH': '0',
#      'ADDR_WIDTH': '7',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '0',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '8',
#      'NUM_WRITE_OUTSTANDING': '8',
#      'MAX_BURST_LENGTH': '1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0'},
#     'registers': {},
#     'driver': pynq_composable.switch.StreamSwitch,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148204544,
#     'addr_range': 65536,
#     'fullpath': 'composable/axis_switch'},
#    'colorthresholding_accel': {'type': 'xilinx.com:hls:colorthresholding_accel:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '7',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_colorthresholding_accel_0',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': '21',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x80100000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x8010FFFF',
#      'ADDR_WIDTH': '7',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '3',
#      'TDEST_WIDTH': '1',
#      'TID_WIDTH': '1',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'CTRL': {'address_offset': 0,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Control signals',
#       'fields': {'AP_START': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'ap_start'."},
#        'AP_DONE': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_done'."},
#        'AP_IDLE': {'bit_offset': 2,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_idle'."},
#        'AP_READY': {'bit_offset': 3,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_ready'."},
#        'RESERVED_1': {'bit_offset': 4,
#         'bit_width': 3,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'AUTO_RESTART': {'bit_offset': 7,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'auto_restart'."},
#        'RESERVED_2': {'bit_offset': 8,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'INTERRUPT': {'bit_offset': 9,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'interrupt'."},
#        'RESERVED_3': {'bit_offset': 10,
#         'bit_width': 22,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'GIER': {'address_offset': 4,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Global Interrupt Enable Register',
#       'fields': {'Enable': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#        'RESERVED': {'bit_offset': 1,
#         'bit_width': 31,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_IER': {'address_offset': 8,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Enable Register',
#       'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'CHAN1_INT_EN': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_ISR': {'address_offset': 12,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Status Register',
#       'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#        'CHAN1_INT_ST': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'rows': {'address_offset': 16,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of rows',
#       'fields': {'rows': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of rows'}}},
#      'cols': {'address_offset': 24,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of cols',
#       'fields': {'cols': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of cols'}}},
#      'Memory_lower_threshold': {'address_offset': 32,
#       'size': 16,
#       'access': 'read-write',
#       'description': 'Memory lower_threshold',
#       'fields': {}},
#      'Memory_upper_threshold': {'address_offset': 96,
#       'size': 16,
#       'access': 'read-write',
#       'description': 'Memory upper_threshold',
#       'fields': {}}},
#     'driver': pynq_composable.libs.ColorThreshold,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148532224,
#     'addr_range': 65536,
#     'fullpath': 'composable/colorthresholding_accel'},
#    'filter2d_accel': {'type': 'xilinx.com:hls:filter2d_accel:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '7',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_filter2d_accel_0',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': '127',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x800C0000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x800CFFFF',
#      'ADDR_WIDTH': '7',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '3',
#      'TDEST_WIDTH': '1',
#      'TID_WIDTH': '1',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'CTRL': {'address_offset': 0,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Control signals',
#       'fields': {'AP_START': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'ap_start'."},
#        'AP_DONE': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_done'."},
#        'AP_IDLE': {'bit_offset': 2,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_idle'."},
#        'AP_READY': {'bit_offset': 3,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_ready'."},
#        'RESERVED_1': {'bit_offset': 4,
#         'bit_width': 3,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'AUTO_RESTART': {'bit_offset': 7,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'auto_restart'."},
#        'RESERVED_2': {'bit_offset': 8,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'INTERRUPT': {'bit_offset': 9,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'interrupt'."},
#        'RESERVED_3': {'bit_offset': 10,
#         'bit_width': 22,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'GIER': {'address_offset': 4,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Global Interrupt Enable Register',
#       'fields': {'Enable': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#        'RESERVED': {'bit_offset': 1,
#         'bit_width': 31,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_IER': {'address_offset': 8,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Enable Register',
#       'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'CHAN1_INT_EN': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_ISR': {'address_offset': 12,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Status Register',
#       'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#        'CHAN1_INT_ST': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'rows': {'address_offset': 16,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of rows',
#       'fields': {'rows': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of rows'}}},
#      'cols': {'address_offset': 24,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of cols',
#       'fields': {'cols': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of cols'}}},
#      'shift': {'address_offset': 32,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of shift',
#       'fields': {'shift': {'bit_offset': 0,
#         'bit_width': 8,
#         'access': 'write-only',
#         'description': 'Bit 7 to 0 of shift'},
#        'RESERVED': {'bit_offset': 8,
#         'bit_width': 24,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'Memory_filter': {'address_offset': 64,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Memory filter',
#       'fields': {}}},
#     'driver': pynq_composable.libs.Filter2d,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148270080,
#     'addr_range': 65536,
#     'fullpath': 'composable/filter2d_accel'},
#    'gray2rgb_accel': {'type': 'xilinx.com:hls:gray2rgb_accel:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_gray2rgb_accel_0',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': '2077926',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x800D0000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x800DFFFF',
#      'ADDR_WIDTH': '5',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '3',
#      'TDEST_WIDTH': '1',
#      'TID_WIDTH': '1',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'CTRL': {'address_offset': 0,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Control signals',
#       'fields': {'AP_START': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'ap_start'."},
#        'AP_DONE': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_done'."},
#        'AP_IDLE': {'bit_offset': 2,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_idle'."},
#        'AP_READY': {'bit_offset': 3,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_ready'."},
#        'RESERVED_1': {'bit_offset': 4,
#         'bit_width': 3,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'AUTO_RESTART': {'bit_offset': 7,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'auto_restart'."},
#        'RESERVED_2': {'bit_offset': 8,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'INTERRUPT': {'bit_offset': 9,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'interrupt'."},
#        'RESERVED_3': {'bit_offset': 10,
#         'bit_width': 22,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'GIER': {'address_offset': 4,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Global Interrupt Enable Register',
#       'fields': {'Enable': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#        'RESERVED': {'bit_offset': 1,
#         'bit_width': 31,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_IER': {'address_offset': 8,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Enable Register',
#       'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'CHAN1_INT_EN': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_ISR': {'address_offset': 12,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Status Register',
#       'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#        'CHAN1_INT_ST': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'rows': {'address_offset': 16,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of rows',
#       'fields': {'rows': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of rows'}}},
#      'cols': {'address_offset': 24,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of cols',
#       'fields': {'cols': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of cols'}}}},
#     'driver': pynq_composable.libs.VitisVisionIP,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148335616,
#     'addr_range': 65536,
#     'fullpath': 'composable/gray2rgb_accel'},
#    'lut_accel': {'type': 'xilinx.com:hls:lut_accel:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '11',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_lut_accel_0',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': '2081938',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x800A0000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x800AFFFF',
#      'ADDR_WIDTH': '11',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '3',
#      'TDEST_WIDTH': '1',
#      'TID_WIDTH': '1',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'CTRL': {'address_offset': 0,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Control signals',
#       'fields': {'AP_START': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'ap_start'."},
#        'AP_DONE': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_done'."},
#        'AP_IDLE': {'bit_offset': 2,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_idle'."},
#        'AP_READY': {'bit_offset': 3,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_ready'."},
#        'RESERVED_1': {'bit_offset': 4,
#         'bit_width': 3,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'AUTO_RESTART': {'bit_offset': 7,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'auto_restart'."},
#        'RESERVED_2': {'bit_offset': 8,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'INTERRUPT': {'bit_offset': 9,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'interrupt'."},
#        'RESERVED_3': {'bit_offset': 10,
#         'bit_width': 22,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'GIER': {'address_offset': 4,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Global Interrupt Enable Register',
#       'fields': {'Enable': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#        'RESERVED': {'bit_offset': 1,
#         'bit_width': 31,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_IER': {'address_offset': 8,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Enable Register',
#       'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'CHAN1_INT_EN': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_ISR': {'address_offset': 12,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Status Register',
#       'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#        'CHAN1_INT_ST': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'rows': {'address_offset': 16,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of rows',
#       'fields': {'rows': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of rows'}}},
#      'cols': {'address_offset': 24,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of cols',
#       'fields': {'cols': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of cols'}}},
#      'Memory_lut': {'address_offset': 1024,
#       'size': 1024,
#       'access': 'read-write',
#       'description': 'Memory lut',
#       'fields': {}}},
#     'driver': pynq_composable.libs.PixelLut,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148139008,
#     'addr_range': 65536,
#     'fullpath': 'composable/lut_accel'},
#    'pipeline_control': {'type': 'xilinx.com:ip:axi_gpio:2.0',
#     'mem_id': 'S_AXI',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_FAMILY': 'zynquplus',
#      'C_S_AXI_ADDR_WIDTH': '9',
#      'C_S_AXI_DATA_WIDTH': '32',
#      'C_GPIO_WIDTH': '1',
#      'C_GPIO2_WIDTH': '6',
#      'C_ALL_INPUTS': '0',
#      'C_ALL_INPUTS_2': '0',
#      'C_ALL_OUTPUTS': '1',
#      'C_ALL_OUTPUTS_2': '0',
#      'C_INTERRUPT_PRESENT': '0',
#      'C_DOUT_DEFAULT': '0x00000000',
#      'C_TRI_DEFAULT': '0xFFFFFFFF',
#      'C_IS_DUAL': '1',
#      'C_DOUT_DEFAULT_2': '0x00000000',
#      'C_TRI_DEFAULT_2': '0xFFFFFFFF',
#      'Component_Name': 'video_cp_pipeline_control_0',
#      'USE_BOARD_FLOW': 'false',
#      'GPIO_BOARD_INTERFACE': 'Custom',
#      'GPIO2_BOARD_INTERFACE': 'Custom',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_BASEADDR': '0x80110000',
#      'C_HIGHADDR': '0x8011FFFF',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'ADDR_WIDTH': '9',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '8',
#      'NUM_WRITE_OUTSTANDING': '8',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0'},
#     'registers': {'GPIO_DATA': {'address_offset': 0,
#       'size': 1,
#       'access': 'read-write',
#       'description': 'Channel-1 AXI GPIO Data register',
#       'fields': {'Channel_1_GPIO_DATA': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'AXI GPIO Data Register.\nFor each I/O bit programmed as input\n  R - Reads value on the input pin.\n  W - No effect.\nFor each I/O bit programmed as output\n  R - Reads value on GPIO_O pins\n  W - Writes value to the corresponding AXI GPIO \n      data register bit and output pin\n'}}},
#      'GPIO_TRI': {'address_offset': 4,
#       'size': 1,
#       'access': 'read-write',
#       'description': 'Channel-1 AXI GPIO 3-State Control register',
#       'fields': {'Channel_1_GPIO_TRI': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'AXI GPIO 3-State Control Register\nEach I/O pin of the AXI GPIO is individually programmable as an input or output   For each of the bits     0 - I/O pin configured as output     1 - I/O pin configured as input\n'}}},
#      'GPIO2_DATA': {'address_offset': 8,
#       'size': 6,
#       'access': 'read-write',
#       'description': 'Channel-2 AXI GPIO Data register',
#       'fields': {'Channel_2_GPIO_DATA': {'bit_offset': 0,
#         'bit_width': 6,
#         'access': 'read-write',
#         'description': 'AXI GPIO Data Register.\nFor each I/O bit programmed as input\n  R - Reads value on the input pin.\n  W - No effect.\nFor each I/O bit programmed as output\n  R - Reads value on GPIO_O pins\n  W - Writes value to the corresponding AXI GPIO \n      data register bit and output pin\n'}}},
#      'GPIO2_TRI': {'address_offset': 12,
#       'size': 6,
#       'access': 'read-write',
#       'description': 'Channel-2 AXI GPIO 3-State Control register',
#       'fields': {'Channel_2_GPIO_TRI': {'bit_offset': 0,
#         'bit_width': 6,
#         'access': 'read-write',
#         'description': 'AXI GPIO 3-State Control Register\nEach I/O pin of the AXI GPIO is individually programmable as an input or output   For each of the bits     0 - I/O pin configured as output     1 - I/O pin configured as input\n'}}},
#      'GIER': {'address_offset': 284,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Global_Interrupt_Enable register',
#       'fields': {'Global_Interrupt_Enable': {'bit_offset': 31,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Master enable for the device interrupt output\n  0 - Disabled\n  1 - Enabled\n'}}},
#      'IP_IER': {'address_offset': 296,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Enable register',
#       'fields': {'Channel_1_Interrupt_Enable': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 1 Interrupt\n  0 - Disabled (masked)\n  1 - Enabled\n'},
#        'Channel_2_Interrupt_Enable': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 2 Interrupt\n  0 - Disabled (masked)\n  1 - Enabled\n'}}},
#      'IP_ISR': {'address_offset': 288,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Status register',
#       'fields': {'Channel_1_Interrupt_Status': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Channel 1 Interrupt Status\n  0 - No Channel 1 input interrupt\n  1 - Channel 1 input interrupt\n'},
#        'Channel_2_Interrupt_Status': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Channel 2 Interrupt Status\n  0 - No Channel 2 input interrupt\n  1 - Channel 2 input interrupt\n'}}}},
#     'driver': pynq.lib.axigpio.AxiGPIO,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148597760,
#     'addr_range': 65536,
#     'fullpath': 'composable/pipeline_control'},
#    'rgb2gray_accel': {'type': 'xilinx.com:hls:rgb2gray_accel:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_rgb2gray_accel_0',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': '2083327',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x800E0000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x800EFFFF',
#      'ADDR_WIDTH': '5',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '3',
#      'TDEST_WIDTH': '1',
#      'TID_WIDTH': '1',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'CTRL': {'address_offset': 0,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Control signals',
#       'fields': {'AP_START': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'ap_start'."},
#        'AP_DONE': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_done'."},
#        'AP_IDLE': {'bit_offset': 2,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_idle'."},
#        'AP_READY': {'bit_offset': 3,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'ap_ready'."},
#        'RESERVED_1': {'bit_offset': 4,
#         'bit_width': 3,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'AUTO_RESTART': {'bit_offset': 7,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': "Control signal Register for 'auto_restart'."},
#        'RESERVED_2': {'bit_offset': 8,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'},
#        'INTERRUPT': {'bit_offset': 9,
#         'bit_width': 1,
#         'access': 'read-only',
#         'description': "Control signal Register for 'interrupt'."},
#        'RESERVED_3': {'bit_offset': 10,
#         'bit_width': 22,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'GIER': {'address_offset': 4,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'Global Interrupt Enable Register',
#       'fields': {'Enable': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#        'RESERVED': {'bit_offset': 1,
#         'bit_width': 31,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_IER': {'address_offset': 8,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'IP Interrupt Enable Register',
#       'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'CHAN1_INT_EN': {'bit_offset': 1,
#         'bit_width': 1,
#         'access': 'read-write',
#         'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#        'RESERVED_0': {'bit_offset': 2,
#         'bit_width': 30,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}},
#      'IP_ISR': {'address_offset': 12,
#       'size': 32,
#       'access': 'read-write',
# ...
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 9\n'}}},
#      'MM2S_SA10': {'address_offset': 128,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 10',
#       'fields': {'Start_Address10': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 10\n'}}},
#      'MM2S_SA11': {'address_offset': 132,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 11',
#       'fields': {'Start_Address11': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 11\n'}}},
#      'MM2S_SA12': {'address_offset': 136,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 12',
#       'fields': {'Start_Address12': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 12\n'}}},
#      'MM2S_SA13': {'address_offset': 140,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 13',
#       'fields': {'Start_Address13': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 13\n'}}},
#      'MM2S_SA14': {'address_offset': 144,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 14',
#       'fields': {'Start_Address14': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 14\n'}}},
#      'MM2S_SA15': {'address_offset': 148,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 15',
#       'fields': {'Start_Address15': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 15\n'}}},
#      'MM2S_SA16': {'address_offset': 152,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'MM2S Start Address Register 16',
#       'fields': {'Start_Address16': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 16\n'}}},
#      'S2MM_VSIZE': {'address_offset': 160,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Vertical Size',
#       'fields': {'Vertical_Size': {'bit_offset': 0,
#         'bit_width': 13,
#         'access': 'read-write',
#         'description': 'Indicates the vertical size in lines of the video data to transfer.\nNote: Writing a value of zero in this field causes a VDMAIntErr to be flagged in the S2MM_VDMASR register on the next frame boundary.\n'}}},
#      'S2MM_HSIZE': {'address_offset': 164,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Horizontal Size',
#       'fields': {'Horizontal_Size': {'bit_offset': 0,
#         'bit_width': 16,
#         'access': 'read-write',
#         'description': 'Indicates the horizontal size in bytes of the video data to transfer.\nNote: A value of zero in this field when S2MM_VSIZE is written causes a VDMAIntErr to be flagged in the S2MM_VDMASR register on the next frame boundary.\n'}}},
#      'S2MM_FRMDLY_STRIDE': {'address_offset': 168,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Frame Delay and Stride',
#       'fields': {'Stride': {'bit_offset': 0,
#         'bit_width': 16,
#         'access': 'read-write',
#         'description': 'Indicates the number of address bytes between the first pixels of each video line.\nNote: A stride value less than S2MM_HSIZE causes data to be corrupted.\n'},
#        'Frame_Delay': {'bit_offset': 24,
#         'bit_width': 5,
#         'access': 'read-write',
#         'description': 'Indicates the minimum number of frame buffers the Genlock slave is to be behind the locked master. This field is only used if the channel is enabled for Genlock Slave operations. This field has no meaning in other Genlock modes.\nNote: Frame Delay must be less than or equal to Frame Buffers or an undefined results occur.\n'}}},
#      'S2MM_SA1': {'address_offset': 172,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 1',
#       'fields': {'Start_Address1': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 1\n'}}},
#      'S2MM_SA2': {'address_offset': 176,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 2',
#       'fields': {'Start_Address2': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 2\n'}}},
#      'S2MM_SA3': {'address_offset': 180,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 3',
#       'fields': {'Start_Address3': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 3\n'}}},
#      'S2MM_SA4': {'address_offset': 184,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 4',
#       'fields': {'Start_Address4': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 4\n'}}},
#      'S2MM_SA5': {'address_offset': 188,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 5',
#       'fields': {'Start_Address5': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 5\n'}}},
#      'S2MM_SA6': {'address_offset': 192,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 6',
#       'fields': {'Start_Address6': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 6\n'}}},
#      'S2MM_SA7': {'address_offset': 196,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 7',
#       'fields': {'Start_Address7': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 7\n'}}},
#      'S2MM_SA8': {'address_offset': 200,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 8',
#       'fields': {'Start_Address8': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 8\n'}}},
#      'S2MM_SA9': {'address_offset': 204,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 9',
#       'fields': {'Start_Address9': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 9\n'}}},
#      'S2MM_SA10': {'address_offset': 208,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 10',
#       'fields': {'Start_Address10': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 10\n'}}},
#      'S2MM_SA11': {'address_offset': 212,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 11',
#       'fields': {'Start_Address11': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 11\n'}}},
#      'S2MM_SA12': {'address_offset': 216,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 12',
#       'fields': {'Start_Address12': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 12\n'}}},
#      'S2MM_SA13': {'address_offset': 220,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 13',
#       'fields': {'Start_Address13': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 13\n'}}},
#      'S2MM_SA14': {'address_offset': 224,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 14',
#       'fields': {'Start_Address14': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 14\n'}}},
#      'S2MM_SA15': {'address_offset': 228,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 15',
#       'fields': {'Start_Address15': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 15\n'}}},
#      'S2MM_SA16': {'address_offset': 232,
#       'size': 32,
#       'access': 'read-write',
#       'description': 'S2MM Start Address Register 16',
#       'fields': {'Start_Address16': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'read-write',
#         'description': 'Indicates the Start Address for video buffer 16\n'}}}},
#     'driver': pynq.lib.video.dma.AxiVDMA,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2147876864,
#     'addr_range': 4096,
#     'fullpath': 'video/axi_vdma'},
#    'pixel_pack': {'type': 'xilinx.com:hls:pixel_pack_2:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_pixel_pack_1',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': 'undef',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x80070000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x8007FFFF',
#      'ADDR_WIDTH': '5',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '6',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'TDEST_WIDTH': '0',
#      'TID_WIDTH': '0',
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'mode': {'address_offset': 16,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of mode',
#       'fields': {'mode': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of mode'}}},
#      'alpha': {'address_offset': 24,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of alpha',
#       'fields': {'alpha': {'bit_offset': 0,
#         'bit_width': 8,
#         'access': 'write-only',
#         'description': 'Bit 7 to 0 of alpha'},
#        'RESERVED': {'bit_offset': 8,
#         'bit_width': 24,
#         'access': 'read-only',
#         'description': 'Reserved.  0s on read.'}}}},
#     'driver': pynq.lib.video.pipeline.PixelPacker,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2147942400,
#     'addr_range': 65536,
#     'fullpath': 'video/pixel_pack'},
#    'pixel_unpack': {'type': 'xilinx.com:hls:pixel_unpack_2:1.0',
#     'mem_id': 's_axi_control',
#     'memtype': 'REGISTER',
#     'gpio': {},
#     'interrupts': {},
#     'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#      'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#      'Component_Name': 'video_cp_pixel_unpack_0',
#      'clk_period': '3.3',
#      'machine': '64',
#      'combinational': '0',
#      'latency': 'undef',
#      'II': 'x',
#      'EDK_IPTYPE': 'PERIPHERAL',
#      'C_S_AXI_CONTROL_BASEADDR': '0x80080000',
#      'C_S_AXI_CONTROL_HIGHADDR': '0x8008FFFF',
#      'ADDR_WIDTH': '5',
#      'DATA_WIDTH': '32',
#      'PROTOCOL': 'AXI4LITE',
#      'READ_WRITE_MODE': 'READ_WRITE',
#      'FREQ_HZ': '299997009',
#      'ID_WIDTH': '0',
#      'AWUSER_WIDTH': '0',
#      'ARUSER_WIDTH': '0',
#      'WUSER_WIDTH': '0',
#      'RUSER_WIDTH': '0',
#      'BUSER_WIDTH': '0',
#      'HAS_BURST': '0',
#      'HAS_LOCK': '0',
#      'HAS_PROT': '0',
#      'HAS_CACHE': '0',
#      'HAS_QOS': '0',
#      'HAS_REGION': '0',
#      'HAS_WSTRB': '1',
#      'HAS_BRESP': '1',
#      'HAS_RRESP': '1',
#      'SUPPORTS_NARROW_BURST': '0',
#      'NUM_READ_OUTSTANDING': '1',
#      'NUM_WRITE_OUTSTANDING': '1',
#      'MAX_BURST_LENGTH': '1',
#      'PHASE': '0.0',
#      'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#      'NUM_READ_THREADS': '1',
#      'NUM_WRITE_THREADS': '1',
#      'RUSER_BITS_PER_BYTE': '0',
#      'WUSER_BITS_PER_BYTE': '0',
#      'INSERT_VIP': '0',
#      'TDATA_NUM_BYTES': '8',
#      'TUSER_WIDTH': '1',
#      'LAYERED_METADATA': None,
#      'TDEST_WIDTH': '0',
#      'TID_WIDTH': '0',
#      'HAS_TREADY': '1',
#      'HAS_TSTRB': '1',
#      'HAS_TKEEP': '1',
#      'HAS_TLAST': '1'},
#     'registers': {'mode': {'address_offset': 16,
#       'size': 32,
#       'access': 'write-only',
#       'description': 'Data signal of mode',
#       'fields': {'mode': {'bit_offset': 0,
#         'bit_width': 32,
#         'access': 'write-only',
#         'description': 'Bit 31 to 0 of mode'}}}},
#     'driver': pynq.lib.video.pipeline.PixelPacker,
#     'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#     'state': None,
#     'bdtype': None,
#     'phys_addr': 2148007936,
#     'addr_range': 65536,
#     'fullpath': 'video/pixel_unpack'}},
#   'memories': {},
#   'hierarchies': {},
#   'interrupts': {},
#   'gpio': {},
#   'fullpath': 'video',
#   'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#   'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#   'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>},
#  'composable/pr_0': {'ip': {},
#   'memories': {},
#   'hierarchies': {},
#   'interrupts': {},
#   'gpio': {},
#   'fullpath': 'composable/pr_0',
#   'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#   'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#   'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>},
#  'composable/pr_1': {'ip': {},
#   'memories': {},
#   'hierarchies': {},
#   'interrupts': {},
#   'gpio': {},
#   'fullpath': 'composable/pr_1',
#   'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#   'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#   'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>},
#  'composable/pr_2': {'ip': {},
#   'memories': {},
#   'hierarchies': {},
#   'interrupts': {},
#   'gpio': {},
#   'fullpath': 'composable/pr_2',
#   'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#   'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#   'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>}}

# %% [markdown]
# We can verify that pynq has assigned the `Composable` class by checking pynq `.hierarchy_dict`

# %%
ol.hierarchy_dict['composable']
# Out:
# {'ip': {'axis_switch': {'type': 'xilinx.com:ip:axis_switch:1.1',
#    'mem_id': 'S_AXI_CTRL',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_FAMILY': 'zynquplus',
#     'C_NUM_SI_SLOTS': '16',
#     'C_LOG_SI_SLOTS': '4',
#     'C_NUM_MI_SLOTS': '15',
#     'C_AXIS_TDATA_WIDTH': '24',
#     'C_AXIS_TID_WIDTH': '1',
#     'C_AXIS_TDEST_WIDTH': '1',
#     'C_AXIS_TUSER_WIDTH': '1',
#     'C_AXIS_SIGNAL_SET': '0b00000000000000000000000010010011',
#     'C_ARB_ON_MAX_XFERS': '1',
#     'C_ARB_ON_NUM_CYCLES': '0',
#     'C_ARB_ON_TLAST': '0',
#     'C_INCLUDE_ARBITER': '1',
#     'C_ARB_ALGORITHM': '0',
#     'C_OUTPUT_REG': '0',
#     'C_DECODER_REG': '1',
#     'C_M_AXIS_CONNECTIVITY_ARRAY': '0b111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111',
#     'C_M_AXIS_BASETDEST_ARRAY': '0b010101010101010',
#     'C_M_AXIS_HIGHTDEST_ARRAY': '0b010101010101010',
#     'C_ROUTING_MODE': '1',
#     'C_S_AXI_CTRL_ADDR_WIDTH': '7',
#     'C_S_AXI_CTRL_DATA_WIDTH': '32',
#     'C_COMMON_CLOCK': '0',
#     'NUM_SI': '16',
#     'NUM_MI': '15',
#     'ROUTING_MODE': '1',
#     'HAS_TREADY': '1',
#     'TDATA_NUM_BYTES': '3',
#     'HAS_TSTRB': '0',
#     'HAS_TKEEP': '0',
#     'HAS_TLAST': '1',
#     'TID_WIDTH': '0',
#     'TDEST_WIDTH': '0',
#     'TUSER_WIDTH': '1',
#     'HAS_ACLKEN': '0',
#     'ARB_ON_MAX_XFERS': '1',
#     'ARB_ON_NUM_CYCLES': '0',
#     'ARB_ON_TLAST': '0',
#     'ARB_ALGORITHM': '0',
#     'DECODER_REG': '1',
#     'OUTPUT_REG': '0',
#     'COMMON_CLOCK': '0',
#     'M00_AXIS_BASETDEST': '0x00000000',
#     'M01_AXIS_BASETDEST': '0x00000001',
#     'M02_AXIS_BASETDEST': '0x00000002',
#     'M03_AXIS_BASETDEST': '0x00000003',
#     'M04_AXIS_BASETDEST': '0x00000004',
#     'M05_AXIS_BASETDEST': '0x00000005',
#     'M06_AXIS_BASETDEST': '0x00000006',
#     'M07_AXIS_BASETDEST': '0x00000007',
#     'M08_AXIS_BASETDEST': '0x00000008',
#     'M09_AXIS_BASETDEST': '0x00000009',
#     'M10_AXIS_BASETDEST': '0x0000000a',
#     'M11_AXIS_BASETDEST': '0x0000000b',
#     'M12_AXIS_BASETDEST': '0x0000000c',
#     'M13_AXIS_BASETDEST': '0x0000000d',
#     'M14_AXIS_BASETDEST': '0x0000000e',
#     'M15_AXIS_BASETDEST': '0x0000000f',
#     'M00_AXIS_HIGHTDEST': '0x00000000',
#     'M01_AXIS_HIGHTDEST': '0x00000001',
#     'M02_AXIS_HIGHTDEST': '0x00000002',
#     'M03_AXIS_HIGHTDEST': '0x00000003',
#     'M04_AXIS_HIGHTDEST': '0x00000004',
#     'M05_AXIS_HIGHTDEST': '0x00000005',
#     'M06_AXIS_HIGHTDEST': '0x00000006',
#     'M07_AXIS_HIGHTDEST': '0x00000007',
#     'M08_AXIS_HIGHTDEST': '0x00000008',
#     'M09_AXIS_HIGHTDEST': '0x00000009',
#     'M10_AXIS_HIGHTDEST': '0x0000000a',
#     'M11_AXIS_HIGHTDEST': '0x0000000b',
#     'M12_AXIS_HIGHTDEST': '0x0000000c',
#     'M13_AXIS_HIGHTDEST': '0x0000000d',
#     'M14_AXIS_HIGHTDEST': '0x0000000e',
#     'M15_AXIS_HIGHTDEST': '0x0000000f',
#     'M00_S00_CONNECTIVITY': '1',
#     'M00_S01_CONNECTIVITY': '1',
#     'M00_S02_CONNECTIVITY': '1',
#     'M00_S03_CONNECTIVITY': '1',
#     'M00_S04_CONNECTIVITY': '1',
#     'M00_S05_CONNECTIVITY': '1',
#     'M00_S06_CONNECTIVITY': '1',
#     'M00_S07_CONNECTIVITY': '1',
#     'M00_S08_CONNECTIVITY': '1',
#     'M00_S09_CONNECTIVITY': '1',
#     'M00_S10_CONNECTIVITY': '1',
#     'M00_S11_CONNECTIVITY': '1',
#     'M00_S12_CONNECTIVITY': '1',
#     'M00_S13_CONNECTIVITY': '1',
#     'M00_S14_CONNECTIVITY': '1',
#     'M00_S15_CONNECTIVITY': '1',
#     'M01_S00_CONNECTIVITY': '1',
#     'M01_S01_CONNECTIVITY': '1',
#     'M01_S02_CONNECTIVITY': '1',
#     'M01_S03_CONNECTIVITY': '1',
#     'M01_S04_CONNECTIVITY': '1',
#     'M01_S05_CONNECTIVITY': '1',
#     'M01_S06_CONNECTIVITY': '1',
#     'M01_S07_CONNECTIVITY': '1',
#     'M01_S08_CONNECTIVITY': '1',
#     'M01_S09_CONNECTIVITY': '1',
#     'M01_S10_CONNECTIVITY': '1',
#     'M01_S11_CONNECTIVITY': '1',
#     'M01_S12_CONNECTIVITY': '1',
#     'M01_S13_CONNECTIVITY': '1',
#     'M01_S14_CONNECTIVITY': '1',
#     'M01_S15_CONNECTIVITY': '1',
#     'M02_S00_CONNECTIVITY': '1',
#     'M02_S01_CONNECTIVITY': '1',
#     'M02_S02_CONNECTIVITY': '1',
#     'M02_S03_CONNECTIVITY': '1',
#     'M02_S04_CONNECTIVITY': '1',
#     'M02_S05_CONNECTIVITY': '1',
#     'M02_S06_CONNECTIVITY': '1',
#     'M02_S07_CONNECTIVITY': '1',
#     'M02_S08_CONNECTIVITY': '1',
#     'M02_S09_CONNECTIVITY': '1',
#     'M02_S10_CONNECTIVITY': '1',
#     'M02_S11_CONNECTIVITY': '1',
#     'M02_S12_CONNECTIVITY': '1',
#     'M02_S13_CONNECTIVITY': '1',
#     'M02_S14_CONNECTIVITY': '1',
#     'M02_S15_CONNECTIVITY': '1',
#     'M03_S00_CONNECTIVITY': '1',
#     'M03_S01_CONNECTIVITY': '1',
#     'M03_S02_CONNECTIVITY': '1',
#     'M03_S03_CONNECTIVITY': '1',
#     'M03_S04_CONNECTIVITY': '1',
#     'M03_S05_CONNECTIVITY': '1',
#     'M03_S06_CONNECTIVITY': '1',
#     'M03_S07_CONNECTIVITY': '1',
#     'M03_S08_CONNECTIVITY': '1',
#     'M03_S09_CONNECTIVITY': '1',
#     'M03_S10_CONNECTIVITY': '1',
#     'M03_S11_CONNECTIVITY': '1',
#     'M03_S12_CONNECTIVITY': '1',
#     'M03_S13_CONNECTIVITY': '1',
#     'M03_S14_CONNECTIVITY': '1',
#     'M03_S15_CONNECTIVITY': '1',
#     'M04_S00_CONNECTIVITY': '1',
#     'M04_S01_CONNECTIVITY': '1',
#     'M04_S02_CONNECTIVITY': '1',
#     'M04_S03_CONNECTIVITY': '1',
#     'M04_S04_CONNECTIVITY': '1',
#     'M04_S05_CONNECTIVITY': '1',
#     'M04_S06_CONNECTIVITY': '1',
#     'M04_S07_CONNECTIVITY': '1',
#     'M04_S08_CONNECTIVITY': '1',
#     'M04_S09_CONNECTIVITY': '1',
#     'M04_S10_CONNECTIVITY': '1',
#     'M04_S11_CONNECTIVITY': '1',
#     'M04_S12_CONNECTIVITY': '1',
#     'M04_S13_CONNECTIVITY': '1',
#     'M04_S14_CONNECTIVITY': '1',
#     'M04_S15_CONNECTIVITY': '1',
#     'M05_S00_CONNECTIVITY': '1',
#     'M05_S01_CONNECTIVITY': '1',
#     'M05_S02_CONNECTIVITY': '1',
#     'M05_S03_CONNECTIVITY': '1',
#     'M05_S04_CONNECTIVITY': '1',
#     'M05_S05_CONNECTIVITY': '1',
#     'M05_S06_CONNECTIVITY': '1',
#     'M05_S07_CONNECTIVITY': '1',
#     'M05_S08_CONNECTIVITY': '1',
#     'M05_S09_CONNECTIVITY': '1',
#     'M05_S10_CONNECTIVITY': '1',
#     'M05_S11_CONNECTIVITY': '1',
#     'M05_S12_CONNECTIVITY': '1',
#     'M05_S13_CONNECTIVITY': '1',
#     'M05_S14_CONNECTIVITY': '1',
#     'M05_S15_CONNECTIVITY': '1',
#     'M06_S00_CONNECTIVITY': '1',
#     'M06_S01_CONNECTIVITY': '1',
#     'M06_S02_CONNECTIVITY': '1',
#     'M06_S03_CONNECTIVITY': '1',
#     'M06_S04_CONNECTIVITY': '1',
#     'M06_S05_CONNECTIVITY': '1',
#     'M06_S06_CONNECTIVITY': '1',
#     'M06_S07_CONNECTIVITY': '1',
#     'M06_S08_CONNECTIVITY': '1',
#     'M06_S09_CONNECTIVITY': '1',
#     'M06_S10_CONNECTIVITY': '1',
#     'M06_S11_CONNECTIVITY': '1',
#     'M06_S12_CONNECTIVITY': '1',
#     'M06_S13_CONNECTIVITY': '1',
#     'M06_S14_CONNECTIVITY': '1',
#     'M06_S15_CONNECTIVITY': '1',
#     'M07_S00_CONNECTIVITY': '1',
#     'M07_S01_CONNECTIVITY': '1',
#     'M07_S02_CONNECTIVITY': '1',
#     'M07_S03_CONNECTIVITY': '1',
#     'M07_S04_CONNECTIVITY': '1',
#     'M07_S05_CONNECTIVITY': '1',
#     'M07_S06_CONNECTIVITY': '1',
#     'M07_S07_CONNECTIVITY': '1',
#     'M07_S08_CONNECTIVITY': '1',
#     'M07_S09_CONNECTIVITY': '1',
#     'M07_S10_CONNECTIVITY': '1',
#     'M07_S11_CONNECTIVITY': '1',
#     'M07_S12_CONNECTIVITY': '1',
#     'M07_S13_CONNECTIVITY': '1',
#     'M07_S14_CONNECTIVITY': '1',
#     'M07_S15_CONNECTIVITY': '1',
#     'M08_S00_CONNECTIVITY': '1',
#     'M08_S01_CONNECTIVITY': '1',
#     'M08_S02_CONNECTIVITY': '1',
#     'M08_S03_CONNECTIVITY': '1',
#     'M08_S04_CONNECTIVITY': '1',
#     'M08_S05_CONNECTIVITY': '1',
#     'M08_S06_CONNECTIVITY': '1',
#     'M08_S07_CONNECTIVITY': '1',
#     'M08_S08_CONNECTIVITY': '1',
#     'M08_S09_CONNECTIVITY': '1',
#     'M08_S10_CONNECTIVITY': '1',
#     'M08_S11_CONNECTIVITY': '1',
#     'M08_S12_CONNECTIVITY': '1',
#     'M08_S13_CONNECTIVITY': '1',
#     'M08_S14_CONNECTIVITY': '1',
#     'M08_S15_CONNECTIVITY': '1',
#     'M09_S00_CONNECTIVITY': '1',
#     'M09_S01_CONNECTIVITY': '1',
#     'M09_S02_CONNECTIVITY': '1',
#     'M09_S03_CONNECTIVITY': '1',
#     'M09_S04_CONNECTIVITY': '1',
#     'M09_S05_CONNECTIVITY': '1',
#     'M09_S06_CONNECTIVITY': '1',
#     'M09_S07_CONNECTIVITY': '1',
#     'M09_S08_CONNECTIVITY': '1',
#     'M09_S09_CONNECTIVITY': '1',
#     'M09_S10_CONNECTIVITY': '1',
#     'M09_S11_CONNECTIVITY': '1',
#     'M09_S12_CONNECTIVITY': '1',
#     'M09_S13_CONNECTIVITY': '1',
#     'M09_S14_CONNECTIVITY': '1',
#     'M09_S15_CONNECTIVITY': '1',
#     'M10_S00_CONNECTIVITY': '1',
#     'M10_S01_CONNECTIVITY': '1',
#     'M10_S02_CONNECTIVITY': '1',
#     'M10_S03_CONNECTIVITY': '1',
#     'M10_S04_CONNECTIVITY': '1',
#     'M10_S05_CONNECTIVITY': '1',
#     'M10_S06_CONNECTIVITY': '1',
#     'M10_S07_CONNECTIVITY': '1',
#     'M10_S08_CONNECTIVITY': '1',
#     'M10_S09_CONNECTIVITY': '1',
#     'M10_S10_CONNECTIVITY': '1',
#     'M10_S11_CONNECTIVITY': '1',
#     'M10_S12_CONNECTIVITY': '1',
#     'M10_S13_CONNECTIVITY': '1',
#     'M10_S14_CONNECTIVITY': '1',
#     'M10_S15_CONNECTIVITY': '1',
#     'M11_S00_CONNECTIVITY': '1',
#     'M11_S01_CONNECTIVITY': '1',
#     'M11_S02_CONNECTIVITY': '1',
#     'M11_S03_CONNECTIVITY': '1',
#     'M11_S04_CONNECTIVITY': '1',
#     'M11_S05_CONNECTIVITY': '1',
#     'M11_S06_CONNECTIVITY': '1',
#     'M11_S07_CONNECTIVITY': '1',
#     'M11_S08_CONNECTIVITY': '1',
#     'M11_S09_CONNECTIVITY': '1',
#     'M11_S10_CONNECTIVITY': '1',
#     'M11_S11_CONNECTIVITY': '1',
#     'M11_S12_CONNECTIVITY': '1',
#     'M11_S13_CONNECTIVITY': '1',
#     'M11_S14_CONNECTIVITY': '1',
#     'M11_S15_CONNECTIVITY': '1',
#     'M12_S00_CONNECTIVITY': '1',
#     'M12_S01_CONNECTIVITY': '1',
#     'M12_S02_CONNECTIVITY': '1',
#     'M12_S03_CONNECTIVITY': '1',
#     'M12_S04_CONNECTIVITY': '1',
#     'M12_S05_CONNECTIVITY': '1',
#     'M12_S06_CONNECTIVITY': '1',
#     'M12_S07_CONNECTIVITY': '1',
#     'M12_S08_CONNECTIVITY': '1',
#     'M12_S09_CONNECTIVITY': '1',
#     'M12_S10_CONNECTIVITY': '1',
#     'M12_S11_CONNECTIVITY': '1',
#     'M12_S12_CONNECTIVITY': '1',
#     'M12_S13_CONNECTIVITY': '1',
#     'M12_S14_CONNECTIVITY': '1',
#     'M12_S15_CONNECTIVITY': '1',
#     'M13_S00_CONNECTIVITY': '1',
#     'M13_S01_CONNECTIVITY': '1',
#     'M13_S02_CONNECTIVITY': '1',
#     'M13_S03_CONNECTIVITY': '1',
#     'M13_S04_CONNECTIVITY': '1',
#     'M13_S05_CONNECTIVITY': '1',
#     'M13_S06_CONNECTIVITY': '1',
#     'M13_S07_CONNECTIVITY': '1',
#     'M13_S08_CONNECTIVITY': '1',
#     'M13_S09_CONNECTIVITY': '1',
#     'M13_S10_CONNECTIVITY': '1',
#     'M13_S11_CONNECTIVITY': '1',
#     'M13_S12_CONNECTIVITY': '1',
#     'M13_S13_CONNECTIVITY': '1',
#     'M13_S14_CONNECTIVITY': '1',
#     'M13_S15_CONNECTIVITY': '1',
#     'M14_S00_CONNECTIVITY': '1',
#     'M14_S01_CONNECTIVITY': '1',
#     'M14_S02_CONNECTIVITY': '1',
#     'M14_S03_CONNECTIVITY': '1',
#     'M14_S04_CONNECTIVITY': '1',
#     'M14_S05_CONNECTIVITY': '1',
#     'M14_S06_CONNECTIVITY': '1',
#     'M14_S07_CONNECTIVITY': '1',
#     'M14_S08_CONNECTIVITY': '1',
#     'M14_S09_CONNECTIVITY': '1',
#     'M14_S10_CONNECTIVITY': '1',
#     'M14_S11_CONNECTIVITY': '1',
#     'M14_S12_CONNECTIVITY': '1',
#     'M14_S13_CONNECTIVITY': '1',
#     'M14_S14_CONNECTIVITY': '1',
#     'M14_S15_CONNECTIVITY': '1',
#     'M15_S00_CONNECTIVITY': '1',
#     'M15_S01_CONNECTIVITY': '1',
#     'M15_S02_CONNECTIVITY': '1',
#     'M15_S03_CONNECTIVITY': '1',
#     'M15_S04_CONNECTIVITY': '1',
#     'M15_S05_CONNECTIVITY': '1',
#     'M15_S06_CONNECTIVITY': '1',
#     'M15_S07_CONNECTIVITY': '1',
#     'M15_S08_CONNECTIVITY': '1',
#     'M15_S09_CONNECTIVITY': '1',
#     'M15_S10_CONNECTIVITY': '1',
#     'M15_S11_CONNECTIVITY': '1',
#     'M15_S12_CONNECTIVITY': '1',
#     'M15_S13_CONNECTIVITY': '1',
#     'M15_S14_CONNECTIVITY': '1',
#     'M15_S15_CONNECTIVITY': '1',
#     'Component_Name': 'video_cp_axis_switch_0',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_BASEADDR': '0x800B0000',
#     'C_HIGHADDR': '0x800BFFFF',
#     'FREQ_HZ': '299997009',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'LAYERED_METADATA': 'undef',
#     'INSERT_VIP': '0',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'ID_WIDTH': '0',
#     'ADDR_WIDTH': '7',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '0',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '8',
#     'NUM_WRITE_OUTSTANDING': '8',
#     'MAX_BURST_LENGTH': '1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0'},
#    'registers': {},
#    'driver': pynq_composable.switch.StreamSwitch,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148204544,
#    'addr_range': 65536,
#    'fullpath': 'composable/axis_switch'},
#   'colorthresholding_accel': {'type': 'xilinx.com:hls:colorthresholding_accel:1.0',
#    'mem_id': 's_axi_control',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '7',
#     'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#     'Component_Name': 'video_cp_colorthresholding_accel_0',
#     'clk_period': '3.3',
#     'machine': '64',
#     'combinational': '0',
#     'latency': '21',
#     'II': 'x',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_S_AXI_CONTROL_BASEADDR': '0x80100000',
#     'C_S_AXI_CONTROL_HIGHADDR': '0x8010FFFF',
#     'ADDR_WIDTH': '7',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '1',
#     'NUM_WRITE_OUTSTANDING': '1',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0',
#     'TDATA_NUM_BYTES': '3',
#     'TDEST_WIDTH': '1',
#     'TID_WIDTH': '1',
#     'TUSER_WIDTH': '1',
#     'LAYERED_METADATA': None,
#     'HAS_TREADY': '1',
#     'HAS_TSTRB': '1',
#     'HAS_TKEEP': '1',
#     'HAS_TLAST': '1'},
#    'registers': {'CTRL': {'address_offset': 0,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Control signals',
#      'fields': {'AP_START': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'ap_start'."},
#       'AP_DONE': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_done'."},
#       'AP_IDLE': {'bit_offset': 2,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_idle'."},
#       'AP_READY': {'bit_offset': 3,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_ready'."},
#       'RESERVED_1': {'bit_offset': 4,
#        'bit_width': 3,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'AUTO_RESTART': {'bit_offset': 7,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'auto_restart'."},
#       'RESERVED_2': {'bit_offset': 8,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'INTERRUPT': {'bit_offset': 9,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'interrupt'."},
#       'RESERVED_3': {'bit_offset': 10,
#        'bit_width': 22,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'GIER': {'address_offset': 4,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global Interrupt Enable Register',
#      'fields': {'Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#       'RESERVED': {'bit_offset': 1,
#        'bit_width': 31,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_IER': {'address_offset': 8,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable Register',
#      'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'CHAN1_INT_EN': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_ISR': {'address_offset': 12,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status Register',
#      'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#       'CHAN1_INT_ST': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'rows': {'address_offset': 16,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of rows',
#      'fields': {'rows': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of rows'}}},
#     'cols': {'address_offset': 24,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of cols',
#      'fields': {'cols': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of cols'}}},
#     'Memory_lower_threshold': {'address_offset': 32,
#      'size': 16,
#      'access': 'read-write',
#      'description': 'Memory lower_threshold',
#      'fields': {}},
#     'Memory_upper_threshold': {'address_offset': 96,
#      'size': 16,
#      'access': 'read-write',
#      'description': 'Memory upper_threshold',
#      'fields': {}}},
#    'driver': pynq_composable.libs.ColorThreshold,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148532224,
#    'addr_range': 65536,
#    'fullpath': 'composable/colorthresholding_accel'},
#   'filter2d_accel': {'type': 'xilinx.com:hls:filter2d_accel:1.0',
#    'mem_id': 's_axi_control',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '7',
#     'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#     'Component_Name': 'video_cp_filter2d_accel_0',
#     'clk_period': '3.3',
#     'machine': '64',
#     'combinational': '0',
#     'latency': '127',
#     'II': 'x',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_S_AXI_CONTROL_BASEADDR': '0x800C0000',
#     'C_S_AXI_CONTROL_HIGHADDR': '0x800CFFFF',
#     'ADDR_WIDTH': '7',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '1',
#     'NUM_WRITE_OUTSTANDING': '1',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0',
#     'TDATA_NUM_BYTES': '3',
#     'TDEST_WIDTH': '1',
#     'TID_WIDTH': '1',
#     'TUSER_WIDTH': '1',
#     'LAYERED_METADATA': None,
#     'HAS_TREADY': '1',
#     'HAS_TSTRB': '1',
#     'HAS_TKEEP': '1',
#     'HAS_TLAST': '1'},
#    'registers': {'CTRL': {'address_offset': 0,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Control signals',
#      'fields': {'AP_START': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'ap_start'."},
#       'AP_DONE': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_done'."},
#       'AP_IDLE': {'bit_offset': 2,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_idle'."},
#       'AP_READY': {'bit_offset': 3,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_ready'."},
#       'RESERVED_1': {'bit_offset': 4,
#        'bit_width': 3,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'AUTO_RESTART': {'bit_offset': 7,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'auto_restart'."},
#       'RESERVED_2': {'bit_offset': 8,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'INTERRUPT': {'bit_offset': 9,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'interrupt'."},
#       'RESERVED_3': {'bit_offset': 10,
#        'bit_width': 22,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'GIER': {'address_offset': 4,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global Interrupt Enable Register',
#      'fields': {'Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#       'RESERVED': {'bit_offset': 1,
#        'bit_width': 31,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_IER': {'address_offset': 8,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable Register',
#      'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'CHAN1_INT_EN': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_ISR': {'address_offset': 12,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status Register',
#      'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#       'CHAN1_INT_ST': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'rows': {'address_offset': 16,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of rows',
#      'fields': {'rows': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of rows'}}},
#     'cols': {'address_offset': 24,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of cols',
#      'fields': {'cols': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of cols'}}},
#     'shift': {'address_offset': 32,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of shift',
#      'fields': {'shift': {'bit_offset': 0,
#        'bit_width': 8,
#        'access': 'write-only',
#        'description': 'Bit 7 to 0 of shift'},
#       'RESERVED': {'bit_offset': 8,
#        'bit_width': 24,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'Memory_filter': {'address_offset': 64,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Memory filter',
#      'fields': {}}},
#    'driver': pynq_composable.libs.Filter2d,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148270080,
#    'addr_range': 65536,
#    'fullpath': 'composable/filter2d_accel'},
#   'gray2rgb_accel': {'type': 'xilinx.com:hls:gray2rgb_accel:1.0',
#    'mem_id': 's_axi_control',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#     'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#     'Component_Name': 'video_cp_gray2rgb_accel_0',
#     'clk_period': '3.3',
#     'machine': '64',
#     'combinational': '0',
#     'latency': '2077926',
#     'II': 'x',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_S_AXI_CONTROL_BASEADDR': '0x800D0000',
#     'C_S_AXI_CONTROL_HIGHADDR': '0x800DFFFF',
#     'ADDR_WIDTH': '5',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '1',
#     'NUM_WRITE_OUTSTANDING': '1',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0',
#     'TDATA_NUM_BYTES': '3',
#     'TDEST_WIDTH': '1',
#     'TID_WIDTH': '1',
#     'TUSER_WIDTH': '1',
#     'LAYERED_METADATA': None,
#     'HAS_TREADY': '1',
#     'HAS_TSTRB': '1',
#     'HAS_TKEEP': '1',
#     'HAS_TLAST': '1'},
#    'registers': {'CTRL': {'address_offset': 0,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Control signals',
#      'fields': {'AP_START': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'ap_start'."},
#       'AP_DONE': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_done'."},
#       'AP_IDLE': {'bit_offset': 2,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_idle'."},
#       'AP_READY': {'bit_offset': 3,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_ready'."},
#       'RESERVED_1': {'bit_offset': 4,
#        'bit_width': 3,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'AUTO_RESTART': {'bit_offset': 7,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'auto_restart'."},
#       'RESERVED_2': {'bit_offset': 8,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'INTERRUPT': {'bit_offset': 9,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'interrupt'."},
#       'RESERVED_3': {'bit_offset': 10,
#        'bit_width': 22,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'GIER': {'address_offset': 4,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global Interrupt Enable Register',
#      'fields': {'Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#       'RESERVED': {'bit_offset': 1,
#        'bit_width': 31,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_IER': {'address_offset': 8,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable Register',
#      'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'CHAN1_INT_EN': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_ISR': {'address_offset': 12,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status Register',
#      'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#       'CHAN1_INT_ST': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'rows': {'address_offset': 16,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of rows',
#      'fields': {'rows': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of rows'}}},
#     'cols': {'address_offset': 24,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of cols',
#      'fields': {'cols': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of cols'}}}},
#    'driver': pynq_composable.libs.VitisVisionIP,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148335616,
#    'addr_range': 65536,
#    'fullpath': 'composable/gray2rgb_accel'},
#   'lut_accel': {'type': 'xilinx.com:hls:lut_accel:1.0',
#    'mem_id': 's_axi_control',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '11',
#     'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#     'Component_Name': 'video_cp_lut_accel_0',
#     'clk_period': '3.3',
#     'machine': '64',
#     'combinational': '0',
#     'latency': '2081938',
#     'II': 'x',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_S_AXI_CONTROL_BASEADDR': '0x800A0000',
#     'C_S_AXI_CONTROL_HIGHADDR': '0x800AFFFF',
#     'ADDR_WIDTH': '11',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '1',
#     'NUM_WRITE_OUTSTANDING': '1',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0',
#     'TDATA_NUM_BYTES': '3',
#     'TDEST_WIDTH': '1',
#     'TID_WIDTH': '1',
#     'TUSER_WIDTH': '1',
#     'LAYERED_METADATA': None,
#     'HAS_TREADY': '1',
#     'HAS_TSTRB': '1',
#     'HAS_TKEEP': '1',
#     'HAS_TLAST': '1'},
#    'registers': {'CTRL': {'address_offset': 0,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Control signals',
#      'fields': {'AP_START': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'ap_start'."},
#       'AP_DONE': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_done'."},
#       'AP_IDLE': {'bit_offset': 2,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_idle'."},
#       'AP_READY': {'bit_offset': 3,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_ready'."},
#       'RESERVED_1': {'bit_offset': 4,
#        'bit_width': 3,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'AUTO_RESTART': {'bit_offset': 7,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'auto_restart'."},
#       'RESERVED_2': {'bit_offset': 8,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'INTERRUPT': {'bit_offset': 9,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'interrupt'."},
#       'RESERVED_3': {'bit_offset': 10,
#        'bit_width': 22,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'GIER': {'address_offset': 4,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global Interrupt Enable Register',
#      'fields': {'Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#       'RESERVED': {'bit_offset': 1,
#        'bit_width': 31,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_IER': {'address_offset': 8,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable Register',
#      'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'CHAN1_INT_EN': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_ISR': {'address_offset': 12,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status Register',
#      'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#       'CHAN1_INT_ST': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'rows': {'address_offset': 16,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of rows',
#      'fields': {'rows': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of rows'}}},
#     'cols': {'address_offset': 24,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of cols',
#      'fields': {'cols': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of cols'}}},
#     'Memory_lut': {'address_offset': 1024,
#      'size': 1024,
#      'access': 'read-write',
#      'description': 'Memory lut',
#      'fields': {}}},
#    'driver': pynq_composable.libs.PixelLut,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148139008,
#    'addr_range': 65536,
#    'fullpath': 'composable/lut_accel'},
#   'pipeline_control': {'type': 'xilinx.com:ip:axi_gpio:2.0',
#    'mem_id': 'S_AXI',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_FAMILY': 'zynquplus',
#     'C_S_AXI_ADDR_WIDTH': '9',
#     'C_S_AXI_DATA_WIDTH': '32',
#     'C_GPIO_WIDTH': '1',
#     'C_GPIO2_WIDTH': '6',
#     'C_ALL_INPUTS': '0',
#     'C_ALL_INPUTS_2': '0',
#     'C_ALL_OUTPUTS': '1',
#     'C_ALL_OUTPUTS_2': '0',
#     'C_INTERRUPT_PRESENT': '0',
#     'C_DOUT_DEFAULT': '0x00000000',
#     'C_TRI_DEFAULT': '0xFFFFFFFF',
#     'C_IS_DUAL': '1',
#     'C_DOUT_DEFAULT_2': '0x00000000',
#     'C_TRI_DEFAULT_2': '0xFFFFFFFF',
#     'Component_Name': 'video_cp_pipeline_control_0',
#     'USE_BOARD_FLOW': 'false',
#     'GPIO_BOARD_INTERFACE': 'Custom',
#     'GPIO2_BOARD_INTERFACE': 'Custom',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_BASEADDR': '0x80110000',
#     'C_HIGHADDR': '0x8011FFFF',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'ADDR_WIDTH': '9',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '8',
#     'NUM_WRITE_OUTSTANDING': '8',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0'},
#    'registers': {'GPIO_DATA': {'address_offset': 0,
#      'size': 1,
#      'access': 'read-write',
#      'description': 'Channel-1 AXI GPIO Data register',
#      'fields': {'Channel_1_GPIO_DATA': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'AXI GPIO Data Register.\nFor each I/O bit programmed as input\n  R - Reads value on the input pin.\n  W - No effect.\nFor each I/O bit programmed as output\n  R - Reads value on GPIO_O pins\n  W - Writes value to the corresponding AXI GPIO \n      data register bit and output pin\n'}}},
#     'GPIO_TRI': {'address_offset': 4,
#      'size': 1,
#      'access': 'read-write',
#      'description': 'Channel-1 AXI GPIO 3-State Control register',
#      'fields': {'Channel_1_GPIO_TRI': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'AXI GPIO 3-State Control Register\nEach I/O pin of the AXI GPIO is individually programmable as an input or output   For each of the bits     0 - I/O pin configured as output     1 - I/O pin configured as input\n'}}},
#     'GPIO2_DATA': {'address_offset': 8,
#      'size': 6,
#      'access': 'read-write',
#      'description': 'Channel-2 AXI GPIO Data register',
#      'fields': {'Channel_2_GPIO_DATA': {'bit_offset': 0,
#        'bit_width': 6,
#        'access': 'read-write',
#        'description': 'AXI GPIO Data Register.\nFor each I/O bit programmed as input\n  R - Reads value on the input pin.\n  W - No effect.\nFor each I/O bit programmed as output\n  R - Reads value on GPIO_O pins\n  W - Writes value to the corresponding AXI GPIO \n      data register bit and output pin\n'}}},
#     'GPIO2_TRI': {'address_offset': 12,
#      'size': 6,
#      'access': 'read-write',
#      'description': 'Channel-2 AXI GPIO 3-State Control register',
#      'fields': {'Channel_2_GPIO_TRI': {'bit_offset': 0,
#        'bit_width': 6,
#        'access': 'read-write',
#        'description': 'AXI GPIO 3-State Control Register\nEach I/O pin of the AXI GPIO is individually programmable as an input or output   For each of the bits     0 - I/O pin configured as output     1 - I/O pin configured as input\n'}}},
#     'GIER': {'address_offset': 284,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global_Interrupt_Enable register',
#      'fields': {'Global_Interrupt_Enable': {'bit_offset': 31,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output\n  0 - Disabled\n  1 - Enabled\n'}}},
#     'IP_IER': {'address_offset': 296,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable register',
#      'fields': {'Channel_1_Interrupt_Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 Interrupt\n  0 - Disabled (masked)\n  1 - Enabled\n'},
#       'Channel_2_Interrupt_Enable': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 2 Interrupt\n  0 - Disabled (masked)\n  1 - Enabled\n'}}},
#     'IP_ISR': {'address_offset': 288,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status register',
#      'fields': {'Channel_1_Interrupt_Status': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Channel 1 Interrupt Status\n  0 - No Channel 1 input interrupt\n  1 - Channel 1 input interrupt\n'},
#       'Channel_2_Interrupt_Status': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Channel 2 Interrupt Status\n  0 - No Channel 2 input interrupt\n  1 - Channel 2 input interrupt\n'}}}},
#    'driver': pynq.lib.axigpio.AxiGPIO,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148597760,
#    'addr_range': 65536,
#    'fullpath': 'composable/pipeline_control'},
#   'rgb2gray_accel': {'type': 'xilinx.com:hls:rgb2gray_accel:1.0',
#    'mem_id': 's_axi_control',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#     'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#     'Component_Name': 'video_cp_rgb2gray_accel_0',
#     'clk_period': '3.3',
#     'machine': '64',
#     'combinational': '0',
#     'latency': '2083327',
#     'II': 'x',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_S_AXI_CONTROL_BASEADDR': '0x800E0000',
#     'C_S_AXI_CONTROL_HIGHADDR': '0x800EFFFF',
#     'ADDR_WIDTH': '5',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '1',
#     'NUM_WRITE_OUTSTANDING': '1',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0',
#     'TDATA_NUM_BYTES': '3',
#     'TDEST_WIDTH': '1',
#     'TID_WIDTH': '1',
#     'TUSER_WIDTH': '1',
#     'LAYERED_METADATA': None,
#     'HAS_TREADY': '1',
#     'HAS_TSTRB': '1',
#     'HAS_TKEEP': '1',
#     'HAS_TLAST': '1'},
#    'registers': {'CTRL': {'address_offset': 0,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Control signals',
#      'fields': {'AP_START': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'ap_start'."},
#       'AP_DONE': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_done'."},
#       'AP_IDLE': {'bit_offset': 2,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_idle'."},
#       'AP_READY': {'bit_offset': 3,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_ready'."},
#       'RESERVED_1': {'bit_offset': 4,
#        'bit_width': 3,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'AUTO_RESTART': {'bit_offset': 7,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'auto_restart'."},
#       'RESERVED_2': {'bit_offset': 8,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'INTERRUPT': {'bit_offset': 9,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'interrupt'."},
#       'RESERVED_3': {'bit_offset': 10,
#        'bit_width': 22,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'GIER': {'address_offset': 4,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global Interrupt Enable Register',
#      'fields': {'Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#       'RESERVED': {'bit_offset': 1,
#        'bit_width': 31,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_IER': {'address_offset': 8,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable Register',
#      'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'CHAN1_INT_EN': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_ISR': {'address_offset': 12,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status Register',
#      'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#       'CHAN1_INT_ST': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'rows': {'address_offset': 16,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of rows',
#      'fields': {'rows': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of rows'}}},
#     'cols': {'address_offset': 24,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of cols',
#      'fields': {'cols': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of cols'}}}},
#    'driver': pynq_composable.libs.VitisVisionIP,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148401152,
#    'addr_range': 65536,
#    'fullpath': 'composable/rgb2gray_accel'},
#   'rgb2hsv_accel': {'type': 'xilinx.com:hls:rgb2hsv_accel:1.0',
#    'mem_id': 's_axi_control',
#    'memtype': 'REGISTER',
#    'gpio': {},
#    'interrupts': {},
#    'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '5',
#     'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#     'Component_Name': 'video_cp_rgb2hsv_accel_0',
#     'clk_period': '3.3',
#     'machine': '64',
#     'combinational': '0',
#     'latency': '22',
#     'II': 'x',
#     'EDK_IPTYPE': 'PERIPHERAL',
#     'C_S_AXI_CONTROL_BASEADDR': '0x800F0000',
#     'C_S_AXI_CONTROL_HIGHADDR': '0x800FFFFF',
#     'ADDR_WIDTH': '5',
#     'DATA_WIDTH': '32',
#     'PROTOCOL': 'AXI4LITE',
#     'READ_WRITE_MODE': 'READ_WRITE',
#     'FREQ_HZ': '299997009',
#     'ID_WIDTH': '0',
#     'AWUSER_WIDTH': '0',
#     'ARUSER_WIDTH': '0',
#     'WUSER_WIDTH': '0',
#     'RUSER_WIDTH': '0',
#     'BUSER_WIDTH': '0',
#     'HAS_BURST': '0',
#     'HAS_LOCK': '0',
#     'HAS_PROT': '0',
#     'HAS_CACHE': '0',
#     'HAS_QOS': '0',
#     'HAS_REGION': '0',
#     'HAS_WSTRB': '1',
#     'HAS_BRESP': '1',
#     'HAS_RRESP': '1',
#     'SUPPORTS_NARROW_BURST': '0',
#     'NUM_READ_OUTSTANDING': '1',
#     'NUM_WRITE_OUTSTANDING': '1',
#     'MAX_BURST_LENGTH': '1',
#     'PHASE': '0.0',
#     'CLK_DOMAIN': 'video_cp_ps_e_0_pl_clk1',
#     'NUM_READ_THREADS': '1',
#     'NUM_WRITE_THREADS': '1',
#     'RUSER_BITS_PER_BYTE': '0',
#     'WUSER_BITS_PER_BYTE': '0',
#     'INSERT_VIP': '0',
#     'TDATA_NUM_BYTES': '3',
#     'TDEST_WIDTH': '1',
#     'TID_WIDTH': '1',
#     'TUSER_WIDTH': '1',
#     'LAYERED_METADATA': None,
#     'HAS_TREADY': '1',
#     'HAS_TSTRB': '1',
#     'HAS_TKEEP': '1',
#     'HAS_TLAST': '1'},
#    'registers': {'CTRL': {'address_offset': 0,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Control signals',
#      'fields': {'AP_START': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'ap_start'."},
#       'AP_DONE': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_done'."},
#       'AP_IDLE': {'bit_offset': 2,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_idle'."},
#       'AP_READY': {'bit_offset': 3,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'ap_ready'."},
#       'RESERVED_1': {'bit_offset': 4,
#        'bit_width': 3,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'AUTO_RESTART': {'bit_offset': 7,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': "Control signal Register for 'auto_restart'."},
#       'RESERVED_2': {'bit_offset': 8,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'},
#       'INTERRUPT': {'bit_offset': 9,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': "Control signal Register for 'interrupt'."},
#       'RESERVED_3': {'bit_offset': 10,
#        'bit_width': 22,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'GIER': {'address_offset': 4,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'Global Interrupt Enable Register',
#      'fields': {'Enable': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#       'RESERVED': {'bit_offset': 1,
#        'bit_width': 31,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_IER': {'address_offset': 8,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Enable Register',
#      'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'CHAN1_INT_EN': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-write',
#        'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'IP_ISR': {'address_offset': 12,
#      'size': 32,
#      'access': 'read-write',
#      'description': 'IP Interrupt Status Register',
#      'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#       'CHAN1_INT_ST': {'bit_offset': 1,
#        'bit_width': 1,
#        'access': 'read-only',
#        'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#       'RESERVED_0': {'bit_offset': 2,
#        'bit_width': 30,
#        'access': 'read-only',
#        'description': 'Reserved.  0s on read.'}}},
#     'rows': {'address_offset': 16,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of rows',
#      'fields': {'rows': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of rows'}}},
#     'cols': {'address_offset': 24,
#      'size': 32,
#      'access': 'write-only',
#      'description': 'Data signal of cols',
#      'fields': {'cols': {'bit_offset': 0,
#        'bit_width': 32,
#        'access': 'write-only',
#        'description': 'Bit 31 to 0 of cols'}}}},
#    'driver': pynq_composable.libs.VitisVisionIP,
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'state': None,
#    'bdtype': None,
#    'phys_addr': 2148466688,
#    'addr_range': 65536,
#    'fullpath': 'composable/rgb2hsv_accel'}},
#  'memories': {},
#  'hierarchies': {'pr_0': {'ip': {},
#    'memories': {},
#    'hierarchies': {},
#    'interrupts': {},
#    'gpio': {},
#    'fullpath': 'composable/pr_0',
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#    'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>},
#   'pr_1': {'ip': {},
#    'memories': {},
#    'hierarchies': {},
#    'interrupts': {},
#    'gpio': {},
#    'fullpath': 'composable/pr_1',
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#    'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>},
#   'pr_2': {'ip': {},
#    'memories': {},
#    'hierarchies': {},
#    'interrupts': {},
#    'gpio': {},
#    'fullpath': 'composable/pr_2',
#    'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#    'driver': <function pynq.overlay.DocumentHierarchy(description)>,
#    'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>}},
#  'interrupts': {},
#  'gpio': {},
#  'fullpath': 'composable',
#  'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xffff7fda25c0>,
#  'driver': pynq_composable.composable.Composable,
#  'overlay': <pynq.overlay.Overlay at 0xffffb3b5ece0>}

# %%
ol?

# %% [markdown]
# Grab a handle to the composable hierarchy this will:
# 1. Perform hardware discovery of the IP cores connected to the AXI4-Stream Switch (either by checking cached file or run the discovery on-the-fly)
# 1. Discovery the DFX regions available in the ComposableOverlay
# 1. Configure the AXI4-Stream Switch with the default values

# %%
cpipe = ol.composable

# %% [markdown]
# ## Explore Composable Dictionary <a class="anchor" id="c_dict"></a>
#
# The `.c_dict` attribute displays all of the IP cores available to compose our pipeline.
#
# These IP cores can be on the static region or in the DFX regions. IP cores on the static region are `[loaded]` by default whereas the IP cores in the DFX regions are `[unloaded]` by default. The `[default]` attribute specify paths that are producer and consumers of data in a given pipeline. These defaults paths, and the path name, can be specified with a [JSON](../overlay/cv_dfx_4_pr_paths.json) file.
#
# If you expand an entry on this dictionary, you will see
# - ci: (consumer interface) the output stream of this IP is connected to this consumer interface on the AXI4-Stream Switch
# - pi: (producer interface) the input stream of this IP is connected from this producer interface on the AXI4-Stream Switch
# - dfx: whether or not the IP is within a DFX region
# - loaded: whether or not the IP is loaded
# - default: (optional) whether the IP is the producer or consumer of a given pipeline

# %%
cpipe.c_dict
# Out:
# {'filter2d_accel': {'si': [2],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'filter2d_accel',
#   'mi': [2]},
#  'lut_accel': {'si': [3],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'lut_accel',
#   'mi': [3]},
#  'rgb2gray_accel': {'si': [4],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'rgb2gray_accel',
#   'mi': [4]},
#  'gray2rgb_accel': {'si': [5],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'gray2rgb_accel',
#   'mi': [5]},
#  'rgb2hsv_accel': {'si': [6],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'rgb2hsv_accel',
#   'mi': [6]},
#  'colorthresholding_accel': {'si': [7],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'colorthresholding_accel',
#   'mi': [7]},
#  'duplicate_accel': {'si': [8, 9],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'axis_broadcaster',
#   'mi': [8]},
#  'pr_0/dilate_accel': {'mi': [9],
#   'si': [10],
#   'modtype': 'dilate_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/erode_accel': {'mi': [10],
#   'si': [11],
#   'modtype': 'erode_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/filter2d_accel': {'mi': [9],
#   'si': [10],
#   'modtype': 'filter2d_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_filter2d_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/axis_data_fifo_0': {'mi': [10],
#   'si': [11],
#   'modtype': 'axis_data_fifo',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/fast_accel': {'mi': [9],
#   'si': [10],
#   'modtype': 'fast_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/cornerHarris_accel': {'mi': [11],
#   'si': [12],
#   'modtype': 'cornerHarris_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/axis_data_fifo_0': {'mi': [12],
#   'si': [13],
#   'modtype': 'axis_data_fifo',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/dilate_accel': {'mi': [11],
#   'si': [12],
#   'modtype': 'dilate_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/erode_accel': {'mi': [12],
#   'si': [13],
#   'modtype': 'erode_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/rgb2xyz_accel': {'mi': [11],
#   'si': [12],
#   'modtype': 'rgb2xyz_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/axis_data_fifo_1': {'mi': [12],
#   'si': [13],
#   'modtype': 'axis_data_fifo',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/absdiff_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'absdiff_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_absdiff_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/add_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'add_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_add_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/subtract_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'subtract_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_subtract_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/bitwise_and_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'bitwise_and_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_bitwise_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'ps_video_in': {'si': [0],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_unpack_2',
#   'default': True,
#   'fullpath': 'video/pixel_unpack'},
#  'ps_video_out': {'mi': [0],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_pack_2',
#   'default': True,
#   'fullpath': 'video/pixel_pack'},
#  'mipi_in': {'si': [1],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'v_proc_ss',
#   'default': True,
#   'fullpath': 'mipi/v_proc_sys'},
#  'mipi_out': {'mi': [1],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_pack_2',
#   'default': True,
#   'fullpath': 'mipi/pixel_pack'}}

# %% [markdown]
# You can also filter by *loaded*, *unloaded* and *default* IP cores using the `.loaded` and `.unloaded` attributes of the `c_dict`

# %%
cpipe.c_dict.loaded
# Out:
# {'filter2d_accel': {'si': [2],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'filter2d_accel',
#   'mi': [2]},
#  'lut_accel': {'si': [3],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'lut_accel',
#   'mi': [3]},
#  'rgb2gray_accel': {'si': [4],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'rgb2gray_accel',
#   'mi': [4]},
#  'gray2rgb_accel': {'si': [5],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'gray2rgb_accel',
#   'mi': [5]},
#  'rgb2hsv_accel': {'si': [6],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'rgb2hsv_accel',
#   'mi': [6]},
#  'colorthresholding_accel': {'si': [7],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'colorthresholding_accel',
#   'mi': [7]},
#  'duplicate_accel': {'si': [8, 9],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'axis_broadcaster',
#   'mi': [8]},
#  'ps_video_in': {'si': [0],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_unpack_2',
#   'default': True,
#   'fullpath': 'video/pixel_unpack'},
#  'ps_video_out': {'mi': [0],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_pack_2',
#   'default': True,
#   'fullpath': 'video/pixel_pack'},
#  'mipi_in': {'si': [1],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'v_proc_ss',
#   'default': True,
#   'fullpath': 'mipi/v_proc_sys'},
#  'mipi_out': {'mi': [1],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_pack_2',
#   'default': True,
#   'fullpath': 'mipi/pixel_pack'}}

# %%
cpipe.c_dict.unloaded
# Out:
# {'pr_0/dilate_accel': {'mi': [9],
#   'si': [10],
#   'modtype': 'dilate_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/erode_accel': {'mi': [10],
#   'si': [11],
#   'modtype': 'erode_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/filter2d_accel': {'mi': [9],
#   'si': [10],
#   'modtype': 'filter2d_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_filter2d_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/axis_data_fifo_0': {'mi': [10],
#   'si': [11],
#   'modtype': 'axis_data_fifo',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_0/fast_accel': {'mi': [9],
#   'si': [10],
#   'modtype': 'fast_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/cornerHarris_accel': {'mi': [11],
#   'si': [12],
#   'modtype': 'cornerHarris_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/axis_data_fifo_0': {'mi': [12],
#   'si': [13],
#   'modtype': 'axis_data_fifo',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/dilate_accel': {'mi': [11],
#   'si': [12],
#   'modtype': 'dilate_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/erode_accel': {'mi': [12],
#   'si': [13],
#   'modtype': 'erode_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/rgb2xyz_accel': {'mi': [11],
#   'si': [12],
#   'modtype': 'rgb2xyz_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_1/axis_data_fifo_1': {'mi': [12],
#   'si': [13],
#   'modtype': 'axis_data_fifo',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/absdiff_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'absdiff_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_absdiff_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/add_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'add_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_add_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/subtract_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'subtract_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_subtract_partial.bit',
#   'dfx': True,
#   'loaded': False},
#  'pr_2/bitwise_and_accel': {'mi': [13, 14],
#   'si': [14],
#   'modtype': 'bitwise_and_accel',
#   'bitstream': 'cv_dfx_3_pr_composable_pr_2_bitwise_partial.bit',
#   'dfx': True,
#   'loaded': False}}

# %%
cpipe.c_dict.default
# Out:
# {'ps_video_in': {'si': [0],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_unpack_2',
#   'default': True,
#   'fullpath': 'video/pixel_unpack'},
#  'ps_video_out': {'mi': [0],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_pack_2',
#   'default': True,
#   'fullpath': 'video/pixel_pack'},
#  'mipi_in': {'si': [1],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'v_proc_ss',
#   'default': True,
#   'fullpath': 'mipi/v_proc_sys'},
#  'mipi_out': {'mi': [1],
#   'dfx': False,
#   'loaded': True,
#   'modtype': 'pixel_pack_2',
#   'default': True,
#   'fullpath': 'mipi/pixel_pack'}}

# %% [markdown]
# ## Explore DFX Dictionary <a class="anchor" id="dfx_dict"></a>
#
# The `.dfx_dict` attribute displays all of the DFX regions available in the composable overlay
#
# If you expand an entry on this dictionary, you will see
# - decoupler: name of the decoupler that handles the DFX regions
# - gpio: PS GPIO pins that enable decouple and status of said decoupler
# - rm: (reconfigurable module) dictionary of partial bitstreams and IP cores contained in them

# %%
cpipe.dfx_dict
# Out:
# {'pr_0': {'decoupler': '/composable/dfx_decouplers/dfx_decoupler_pr_0',
#   'decouple': 0,
#   'status': 3,
#   'rm': {'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit': {'pr_0/dilate_accel': {'interface': ['/pr_0/stream_in0',
#       '/pr_0/stream_out0'],
#      'modtype': 'dilate_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit'},
#     'pr_0/erode_accel': {'interface': ['/pr_0/stream_in1',
#       '/pr_0/stream_out1'],
#      'modtype': 'erode_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_0_dilate_erode_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_0_filter2d_fifo_partial.bit': {'pr_0/filter2d_accel': {'interface': ['/pr_0/stream_in0',
#       '/pr_0/stream_out0'],
#      'modtype': 'filter2d_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_0_filter2d_fifo_partial.bit'},
#     'pr_0/axis_data_fifo_0': {'interface': ['/pr_0/stream_in1',
#       '/pr_0/stream_out1'],
#      'modtype': 'axis_data_fifo',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_0_filter2d_fifo_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit': {'pr_0/fast_accel': {'interface': ['/pr_0/stream_in0',
#       '/pr_0/stream_out0'],
#      'modtype': 'fast_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit'},
#     'pr_0/axis_data_fifo_0': {'interface': ['/pr_0/stream_in1',
#       '/pr_0/stream_out1'],
#      'modtype': 'axis_data_fifo',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_0_fast_fifo_partial.bit'}}}},
#  'pr_1': {'decoupler': '/composable/dfx_decouplers/dfx_decoupler_pr_1',
#   'decouple': 1,
#   'status': 4,
#   'rm': {'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit': {'pr_1/cornerHarris_accel': {'interface': ['/pr_1/stream_in0',
#       '/pr_1/stream_out0'],
#      'modtype': 'cornerHarris_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit'},
#     'pr_1/axis_data_fifo_0': {'interface': ['/pr_1/stream_in1',
#       '/pr_1/stream_out1'],
#      'modtype': 'axis_data_fifo',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_1_cornerharris_fifo_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit': {'pr_1/dilate_accel': {'interface': ['/pr_1/stream_in0',
#       '/pr_1/stream_out0'],
#      'modtype': 'dilate_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit'},
#     'pr_1/erode_accel': {'interface': ['/pr_1/stream_in1',
#       '/pr_1/stream_out1'],
#      'modtype': 'erode_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_1_dilate_erode_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit': {'pr_1/rgb2xyz_accel': {'interface': ['/pr_1/stream_in0',
#       '/pr_1/stream_out0'],
#      'modtype': 'rgb2xyz_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit'},
#     'pr_1/axis_data_fifo_1': {'interface': ['/pr_1/stream_in1',
#       '/pr_1/stream_out1'],
#      'modtype': 'axis_data_fifo',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_1_rgb2xyz_fifo_partial.bit'}}}},
#  'pr_2': {'decoupler': '/composable/dfx_decouplers/dfx_decoupler_pr_2',
#   'decouple': 2,
#   'status': 5,
#   'rm': {'cv_dfx_3_pr_composable_pr_2_absdiff_partial.bit': {'pr_2/absdiff_accel': {'interface': ['/pr_2/stream_in0',
#       '/pr_2/stream_in1',
#       '/pr_2/stream_out0'],
#      'modtype': 'absdiff_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_2_absdiff_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_2_add_partial.bit': {'pr_2/add_accel': {'interface': ['/pr_2/stream_in0',
#       '/pr_2/stream_in1',
#       '/pr_2/stream_out0'],
#      'modtype': 'add_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_2_add_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_2_subtract_partial.bit': {'pr_2/subtract_accel': {'interface': ['/pr_2/stream_in0',
#       '/pr_2/stream_in1',
#       '/pr_2/stream_out0'],
#      'modtype': 'subtract_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_2_subtract_partial.bit'}},
#    'cv_dfx_3_pr_composable_pr_2_bitwise_partial.bit': {'pr_2/bitwise_and_accel': {'interface': ['/pr_2/stream_in0',
#       '/pr_2/stream_in1',
#       '/pr_2/stream_out0'],
#      'modtype': 'bitwise_and_accel',
#      'bitstream': 'cv_dfx_3_pr_composable_pr_2_bitwise_partial.bit'}}}}}

# %% [markdown]
# ## Documentation <a class="anchor" id="docs"></a>
#
# You can get more detailed documentation on any of the classes described above by using the built-in `help()` function. Or using the question mark (`?`)

# %%
from pynq_composable import Composable

# %%
Composable.compose?

# %%
help(Composable)
# Out:
# Help on class Composable in module pynq_composable.composable:
#
# class Composable(pynq.overlay.DefaultHierarchy)
#  |  Composable(description)
#  |
#  |  This class keeps track of a composable overlay
#  |
#  |  The Composable class holds the state of the logic available for run-time
#  |  composition through and AXI4-Stream switch
#  |
#  |  Our definition of composable overlay is: "post-bitstream configurable
#  |  dataflow pipeline". Hence, this class must expose configurability through
#  |  content discovery, dataflow configuration and runtime protection.
#  |
#  |  This class stores two dictionaries: c_dict and dfx_dict
#  |
#  |  Each entry of the Composable dictionary (c_dict) is a mapping:
#  |  'name' -> {si, mi, modtype, dfx, loaded, bitstream}, where
#  |  name (str) is the key of the entry.
#  |  si (list) list of physical port in the switch the IP is connected to
#  |  mi (list) list of physical port in the switch the IP is connected from
#  |  modtype(str) IP type
#  |  dfx (bool) IP is located in a DFX region
#  |  loaded (bool) IP is loaded
#  |  bitstream (str) location of the corresponding partial bitstream
#  |
#  |  Each entry of the DFX dictionary (dfx_dict) dictionary is a mapping:
#  |  'name' -> {decoupler, gpio, ip}, where
#  |  name (str) is the name of the partial region
#  |  decoupler (str) fullpath of the DFX decoupler that controls the dfx region
#  |  gpio (dict) index of PS GPIO that control the DFX decoupler
#  |  ip (dict) dictionary of partial bitstream and IP associated to the region
#  |
#  |  Attributes
#  |  ----------
#  |  graph : Digraph
#  |      Graphviz Digraph representation of the current dataflow pipeline
#  |
#  |  Method resolution order:
#  |      Composable
#  |      pynq.overlay.DefaultHierarchy
#  |      pynq.overlay._IPMap
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __dir__(self)
#  |      Default dir() implementation.
#  |
#  |  __getattr__(self, name)
#  |
#  |  __init__(self, description)
#  |      Return a new Composable object.
#  |
#  |      Performs a hardware discovery where the different IP cores connected
#  |      to the switch are added to the c_dict and the DFX regions are added
#  |      to the dfx_dict
#  |
#  |      Parameters
#  |      ----------
#  |      description : dict
#  |          Description of the hierarchy
#  |
#  |      Note
#  |      ----
#  |      This class requires that partial bitstreams and corresponding HWH files
#  |      to be next to bitstream file that was used to create the Overlay object
#  |      The name convention for partial bitstreams and HWH file is
#  |
#  |      <bitstream_name>_<hierarchy>_<dfx_region>_<dfx_module_name>.{bit|hwh}
#  |
#  |      For instance if the main bitstream is `base.bit` and there are two DFX
#  |      regions with the names `dfx_0` and `dfx_1` each of them with the same
#  |      two reconfigurable module, `function_1` and `function_2` the names
#  |      should be as follow
#  |
#  |          base_composable_dfx_0_function_1.bit
#  |          base_composable_dfx_0_function_1.hwh
#  |          base_composable_dfx_0_function_2.bit
#  |          base_composable_dfx_0_function_2.hwh
#  |          base_composable_dfx_1_function_1.bit
#  |          base_composable_dfx_1_function_1.hwh
#  |          base_composable_dfx_1_function_2.bit
#  |          base_composable_dfx_1_function_2.hwh
#  |
#  |  compose(self, cle_list: list) -> None
#  |      Configure design to implement required dataflow pipeline
#  |
#  |      Parameters
#  |      ----------
#  |      cle_list : list
#  |          list of the composable IP objects
#  |          Examples:
#  |          [a, b, c, d] yields
#  |
#  |          .. code-block:: none
#  |
#  |                  -> a -> b -> c -> d ->
#  |
#  |          [a, b, [[c,d],[e]], f, g] yields
#  |
#  |          .. code-block:: none
#  |
#  |                              -> c -> d -
#  |                            /            \
#  |                  -> a -> b               f -> g ->
#  |                            \            /
#  |                              ---> e ----
#  |
#  |  insert(self, iptuple: tuple) -> None
#  |      Insert a new IP or list of IP into current pipeline
#  |
#  |      Parameters
#  |      ----------
#  |      iptuple: tuple
#  |          Tuple of two items.
#  |          First: list of IP to be inserted
#  |          Second: index
#  |
#  |          Examples:
#  |              ([cpipe.erode], 3)
#  |              ([cpipe.filter2d, cpipe.duplicate], 2)
#  |
#  |  load(self, dfx_list: list) -> None
#  |      Download dfx IP onto the corresponding partial regions
#  |
#  |      Parameters
#  |      ----------
#  |      dfx_list: list
#  |          List of IP to be downloaded onto the dfx regions. The list can
#  |          contain either a string with the fullname or the IP object
#  |
#  |          Examples:
#  |              [cpipe.dfx_0.fast_accel, cpipe.dfx_1.dilate_accel]
#  |              ['dfx_0/fast_accel', 'dfx_1/dilate_accel']
#  |
#  |  remove(self, iplist: list = None) -> None
#  |      Remove IP object from the current pipeline
#  |
#  |      Parameters
#  |      ----------
#  |      iplist: list
#  |          List of IP to be removed from the current pipeline
#  |
#  |          Examples:
#  |              [cpipe.erode]
#  |              [cpipe.filter2d, cpipe.duplicate]
#  |
#  |  replace(self, replaceip: tuple) -> None
#  |      Replace an IP object in the current pipeline
#  |
#  |      Parameters
#  |      ----------
#  |      replaceip: tuple
#  |          Tuple of two items.
#  |          First: IP object to be replaced
#  |          Second: new IP object
#  |
#  |          Examples:
#  |              (cpipe.erode, cpipe.dilate)
#  |
#  |  tap(self, ip: Union[Type[pynq.overlay.DefaultIP], int] = None, sink: bool = True) -> None
#  |      Observe the output of an IP object in the current pipeline
#  |
#  |      Tap into the output of the IP cores in the current pipeline
#  |      Note that tap is not supported in a branch
#  |
#  |      You can tap by passing the IP name or the index of the IP in the list.
#  |
#  |      Note that tap does not modify the attribute current_pipeline
#  |
#  |      Parameters
#  |      ----------
#  |      ip:
#  |          Either an IP object in the current pipeline to be tapped or
#  |          index of IP object in the current pipeline to be tapped
#  |
#  |          Examples:
#  |              tap(cpipe.dilate)
#  |              tap(6)
#  |      sink: bool
#  |          True: Keep sink of original pipeline as sink of tap pipeline
#  |          False: Do not keep sink of original pipeline as sink tap pipeline
#  |
#  |  untap(self) -> None
#  |      Restores current pipeline after tap happened
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  checkhierarchy(description)
#  |      Function to check if the driver matches a particular hierarchy
#  |
#  |      This function should be redefined in derived classes to return True
#  |      if the description matches what is expected by the driver. The default
#  |      implementation always returns False so that drivers that forget don't
#  |      get loaded for hierarchies they don't expect.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  c_dict
#  |      Returns the c_dict dictionary
#  |
#  |      All the IP cores connected to the AXI4-Stream Switch. Key is the name
#  |      of the IP; value is a dictionary mapping the manager and subordinate to
#  |      the switch port, whether the IP is in a dfx region and loaded
#  |      {str: {'si' : list, 'mi' : list, 'modtype': str,
#  |      'dfx': bool, 'loaded': bool, 'bitstream: str'}}.
#  |
#  |  current_pipeline
#  |      List of IP objects in the current dataflow pipeline
#  |
#  |  dfx_dict
#  |      Returns the dfx_dict dictionary
#  |
#  |      All the DFX regions in the hierarchy. Key is the name of the dfx region
#  |      value is a dictionary with DFX decoupler, PS GPIO that controls the DFX
#  |      decoupler and partial bitstreams associated to the region
#  |      {str: {'decoupler' : str, 'gpio' : {'decouple' : int, 'status' : int},
#  |      ip': dict}}.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  dfx_decouple_mode
#  |      Set the operation mode of the dfx decouple logic
#  |
#  |      Parameters
#  |      ----------
#  |      enable : bool
#  |          True: DFX decouple commands are issued
#  |          False: No DFX decouple commands are issued
#  |
#  |  soft_reset_mode
#  |      Set the operation mode of the soft reset logic
#  |
#  |      Parameters
#  |      ----------
#  |      enable : bool
#  |          True: Soft reset command is issued
#  |          False: No soft reset is issued
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pynq.overlay.DefaultHierarchy:
#  |
#  |  download(self, bitfile_name, dtbo=None, program=True)
#  |      Function to download a partial bitstream for the hierarchy block.
#  |
#  |      Since it is hard to know which hierarchy is to be reconfigured by only
#  |      looking at the metadata, we assume users will tell this information.
#  |      Thus, this function should be called only when users are sure about
#  |      the hierarchy name of the partial region.
#  |
#  |      Parameters
#  |      ----------
#  |      bitfile_name : str
#  |          The name of the partial bitstream.
#  |      dtbo : str
#  |          The relative or absolute path of the partial dtbo file.
#  |      program : bool
#  |          Whether the overlay should be downloaded.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pynq.overlay._IPMap:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ## Conclusion <a class="anchor" id="conclusion"></a>
#
# This notebook has introduced the `Composable` class as well as `c_dict` and `dfx_dict`. We will use these dictionaries in the following notebooks to create custom pipelines
#
# | | [First Custom Pipeline ➡️](02_first_custom_pipeline.ipynb)

# %% [markdown]
# Copyright &copy; 2021 Xilinx, Inc
#
# SPDX-License-Identifier: BSD-3-Clause
#
# ----
